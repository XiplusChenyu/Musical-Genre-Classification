# %%
import time
import numpy as np

from basic_model import M_model
import torch
from torch import optim
from util import bce_loss, accuracy_function
from Paras import Para

from data_loader import fin_train_loader, fin_validation_loader, fin_test_loader

Para.dataset_len = len(fin_train_loader)
Para.log_step = len(fin_train_loader) // 4

optimizer = torch.optim.RMSprop(M_model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)


def train(model, epoch, versatile=True):
    start_time = time.time()
    model = model.train()
    train_loss = 0.
    accuracy = 0.
    batch_num = len(fin_train_loader)
    _index = 0

    for _index, data in enumerate(fin_train_loader):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        optimizer.zero_grad()
        predicted = model(spec_input)

        loss_value = bce_loss(predicted, target)
        accuracy_value = accuracy_function(predicted, target)

        loss_value.backward()
        optimizer.step()

        train_loss += loss_value.data.item()
        accuracy += accuracy_value

        if versatile:
            if (_index + 1) % Para.log_step == 0:
                elapsed = time.time() - start_time
                print('Epoch{:3d} | {:3d}/{:3d} batches | {:5.2f}ms/ batch | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
                      .format(epoch, _index + 1, batch_num,
                              elapsed * 1000 / (_index + 1),
                              train_loss / (_index + 1),
                              accuracy * 100 / (_index + 1)))

    train_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('-' * 99)
    print('End of training epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  train_loss, accuracy * 100))

    return train_loss, accuracy


def validate_test(model, epoch, test=False):
    start_time = time.time()
    model = model.eval()
    v_loss = 0.
    accuracy = 0.
    data_loader_use = fin_validation_loader if not test else fin_test_loader
    _index = 0
    for _index, data in enumerate(data_loader_use):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        with torch.no_grad():

            predicted = model(spec_input)

            loss_value = bce_loss(predicted, target)
            accuracy_value = accuracy_function(predicted, target)

            v_loss += loss_value.data.item()
            accuracy += accuracy_value

    v_loss /= (_index + 1)
    accuracy /= (_index + 1)

    if not test:
        print('End of validation epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format(epoch, (time.time() - start_time),
                v_loss, accuracy * 100))
    else:
        print('End of Test | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format((time.time() - start_time),
                v_loss, accuracy * 100))
    print('-' * 99)

    return v_loss, accuracy

# %% [markdown]
# # Train the model here

# %%
Para.cuda
# Out:
# True

# %%
t_loss, t_accu, v_loss, v_accu = [], [], [], []
decay_cnt = 0

for epoch in range(1, Para.epoch_num + 1):
    if Para.cuda:
        M_model.cuda()

    train_loss, train_accuracy = train(M_model, epoch)
    validation_loss, validation_accuracy = validate_test(M_model, epoch, test=False)

    t_loss.append(train_loss)
    t_accu.append(train_accuracy)

    v_loss.append(validation_loss)
    v_accu.append(validation_accuracy)

    # use accuracy to find the best model
    if np.max(t_accu) == t_accu[-1]:
        print('***Found Best Training Model***')
    if np.max(v_accu) == v_accu[-1]:
        with open(Para.MODEL_SAVE_PATH_1A, 'wb') as f:
            torch.save(M_model.cpu().state_dict(), f)
            print('***Best Validation Model Found and Saved***')

    print('-' * 99)

    # Use BCE loss value for learning rate scheduling
    decay_cnt += 1

    if np.min(t_loss) not in t_loss[-3:] and decay_cnt > 2:
        scheduler.step()
        decay_cnt = 0
        print('***Learning rate decreased***')
        print('-' * 99)
# Out:
# Epoch  1 | 154/619 batches | 36.12ms/ batch | BCE: 0.2801 | Accuracy: 31.41% |
# Epoch  1 | 308/619 batches | 36.58ms/ batch | BCE: 0.2611 | Accuracy: 37.32% |
# Epoch  1 | 462/619 batches | 36.06ms/ batch | BCE: 0.2490 | Accuracy: 40.73% |
# Epoch  1 | 616/619 batches | 36.30ms/ batch | BCE: 0.2394 | Accuracy: 43.65% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 22.49s | BCE: 0.2393 | Accuracy: 43.71% |
# End of validation epoch   1 | time:  0.96s | BCE: 0.2120 | Accuracy: 50.87% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 154/619 batches | 35.29ms/ batch | BCE: 0.1934 | Accuracy: 57.39% |
# Epoch  2 | 308/619 batches | 36.16ms/ batch | BCE: 0.1868 | Accuracy: 58.87% |
# Epoch  2 | 462/619 batches | 36.46ms/ batch | BCE: 0.1829 | Accuracy: 59.65% |
# Epoch  2 | 616/619 batches | 36.05ms/ batch | BCE: 0.1793 | Accuracy: 60.57% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 22.34s | BCE: 0.1793 | Accuracy: 60.57% |
# End of validation epoch   2 | time:  0.97s | BCE: 0.1347 | Accuracy: 72.52% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 154/619 batches | 37.36ms/ batch | BCE: 0.1548 | Accuracy: 65.79% |
# Epoch  3 | 308/619 batches | 36.57ms/ batch | BCE: 0.1528 | Accuracy: 67.19% |
# Epoch  3 | 462/619 batches | 36.73ms/ batch | BCE: 0.1504 | Accuracy: 67.82% |
# Epoch  3 | 616/619 batches | 36.23ms/ batch | BCE: 0.1469 | Accuracy: 68.55% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time: 22.45s | BCE: 0.1468 | Accuracy: 68.61% |
# End of validation epoch   3 | time:  0.96s | BCE: 0.1447 | Accuracy: 69.15% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 | 154/619 batches | 37.34ms/ batch | BCE: 0.1301 | Accuracy: 72.24% |
# Epoch  4 | 308/619 batches | 36.54ms/ batch | BCE: 0.1299 | Accuracy: 72.44% |
# Epoch  4 | 462/619 batches | 36.69ms/ batch | BCE: 0.1269 | Accuracy: 73.35% |
# Epoch  4 | 616/619 batches | 36.77ms/ batch | BCE: 0.1250 | Accuracy: 73.74% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time: 22.77s | BCE: 0.1251 | Accuracy: 73.71% |
# End of validation epoch   4 | time:  0.96s | BCE: 0.1275 | Accuracy: 74.23% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 | 154/619 batches | 36.39ms/ batch | BCE: 0.1066 | Accuracy: 79.02% |
# Epoch  5 | 308/619 batches | 36.72ms/ batch | BCE: 0.1075 | Accuracy: 77.82% |
# Epoch  5 | 462/619 batches | 36.40ms/ batch | BCE: 0.1071 | Accuracy: 78.02% |
# Epoch  5 | 616/619 batches | 36.56ms/ batch | BCE: 0.1070 | Accuracy: 78.24% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time: 22.65s | BCE: 0.1069 | Accuracy: 78.24% |
# End of validation epoch   5 | time:  0.96s | BCE: 0.0957 | Accuracy: 79.95% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 | 154/619 batches | 35.24ms/ batch | BCE: 0.0944 | Accuracy: 80.64% |
# Epoch  6 | 308/619 batches | 36.15ms/ batch | BCE: 0.0949 | Accuracy: 81.17% |
# Epoch  6 | 462/619 batches | 36.44ms/ batch | BCE: 0.0929 | Accuracy: 81.36% |
# Epoch  6 | 616/619 batches | 36.27ms/ batch | BCE: 0.0914 | Accuracy: 81.50% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time: 22.49s | BCE: 0.0914 | Accuracy: 81.51% |
# End of validation epoch   6 | time:  0.96s | BCE: 0.1473 | Accuracy: 71.86% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 | 154/619 batches | 37.40ms/ batch | BCE: 0.0800 | Accuracy: 83.89% |
# Epoch  7 | 308/619 batches | 36.60ms/ batch | BCE: 0.0792 | Accuracy: 84.50% |
# Epoch  7 | 462/619 batches | 36.74ms/ batch | BCE: 0.0791 | Accuracy: 84.65% |
# Epoch  7 | 616/619 batches | 36.46ms/ batch | BCE: 0.0784 | Accuracy: 84.71% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time: 22.59s | BCE: 0.0783 | Accuracy: 84.68% |
# End of validation epoch   7 | time:  0.96s | BCE: 0.2347 | Accuracy: 64.29% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 | 154/619 batches | 37.36ms/ batch | BCE: 0.0632 | Accuracy: 88.27% |
# Epoch  8 | 308/619 batches | 36.56ms/ batch | BCE: 0.0662 | Accuracy: 87.13% |
# Epoch  8 | 462/619 batches | 36.73ms/ batch | BCE: 0.0671 | Accuracy: 87.03% |
# Epoch  8 | 616/619 batches | 36.81ms/ batch | BCE: 0.0668 | Accuracy: 87.25% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time: 22.80s | BCE: 0.0668 | Accuracy: 87.23% |
# End of validation epoch   8 | time:  0.90s | BCE: 0.2522 | Accuracy: 60.58% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 | 154/619 batches | 36.65ms/ batch | BCE: 0.0608 | Accuracy: 87.91% |
# Epoch  9 | 308/619 batches | 36.85ms/ batch | BCE: 0.0601 | Accuracy: 88.23% |
# Epoch  9 | 462/619 batches | 36.48ms/ batch | BCE: 0.0585 | Accuracy: 88.80% |
# Epoch  9 | 616/619 batches | 36.63ms/ batch | BCE: 0.0589 | Accuracy: 88.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time: 22.69s | BCE: 0.0588 | Accuracy: 88.84% |
# End of validation epoch   9 | time:  0.96s | BCE: 0.0760 | Accuracy: 85.34% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 | 154/619 batches | 29.15ms/ batch | BCE: 0.0513 | Accuracy: 90.06% |
# Epoch 10 | 308/619 batches | 23.34ms/ batch | BCE: 0.0500 | Accuracy: 90.46% |
# Epoch 10 | 462/619 batches | 21.39ms/ batch | BCE: 0.0519 | Accuracy: 89.92% |
# Epoch 10 | 616/619 batches | 20.43ms/ batch | BCE: 0.0512 | Accuracy: 89.94% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time: 12.66s | BCE: 0.0510 | Accuracy: 89.95% |
# End of validation epoch  10 | time:  0.61s | BCE: 0.0872 | Accuracy: 83.30% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 | 154/619 batches | 18.07ms/ batch | BCE: 0.0385 | Accuracy: 92.69% |
# Epoch 11 | 308/619 batches | 17.92ms/ batch | BCE: 0.0416 | Accuracy: 91.88% |
# Epoch 11 | 462/619 batches | 17.89ms/ batch | BCE: 0.0404 | Accuracy: 92.22% |
# Epoch 11 | 616/619 batches | 17.84ms/ batch | BCE: 0.0410 | Accuracy: 92.19% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time: 11.07s | BCE: 0.0411 | Accuracy: 92.17% |
# End of validation epoch  11 | time:  0.73s | BCE: 0.1644 | Accuracy: 73.17% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 | 154/619 batches | 17.80ms/ batch | BCE: 0.0363 | Accuracy: 92.69% |
# Epoch 12 | 308/619 batches | 17.64ms/ batch | BCE: 0.0366 | Accuracy: 92.90% |
# Epoch 12 | 462/619 batches | 17.58ms/ batch | BCE: 0.0372 | Accuracy: 93.20% |
# Epoch 12 | 616/619 batches | 17.55ms/ batch | BCE: 0.0376 | Accuracy: 92.96% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time: 10.88s | BCE: 0.0377 | Accuracy: 92.95% |
# End of validation epoch  12 | time:  0.59s | BCE: 0.0878 | Accuracy: 84.92% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 | 154/619 batches | 17.85ms/ batch | BCE: 0.0284 | Accuracy: 94.64% |
# Epoch 13 | 308/619 batches | 17.67ms/ batch | BCE: 0.0299 | Accuracy: 94.26% |
# Epoch 13 | 462/619 batches | 17.70ms/ batch | BCE: 0.0318 | Accuracy: 93.99% |
# Epoch 13 | 616/619 batches | 17.71ms/ batch | BCE: 0.0313 | Accuracy: 94.11% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time: 10.98s | BCE: 0.0315 | Accuracy: 94.09% |
# End of validation epoch  13 | time:  0.57s | BCE: 0.0841 | Accuracy: 85.66% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 | 154/619 batches | 17.94ms/ batch | BCE: 0.0290 | Accuracy: 95.37% |
# Epoch 14 | 308/619 batches | 17.80ms/ batch | BCE: 0.0271 | Accuracy: 95.56% |
# Epoch 14 | 462/619 batches | 17.74ms/ batch | BCE: 0.0283 | Accuracy: 95.20% |
# Epoch 14 | 616/619 batches | 17.73ms/ batch | BCE: 0.0292 | Accuracy: 94.87% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time: 10.99s | BCE: 0.0291 | Accuracy: 94.86% |
# End of validation epoch  14 | time:  0.58s | BCE: 0.1480 | Accuracy: 76.33% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 | 154/619 batches | 17.96ms/ batch | BCE: 0.0226 | Accuracy: 96.14% |
# Epoch 15 | 308/619 batches | 17.82ms/ batch | BCE: 0.0232 | Accuracy: 96.00% |
# Epoch 15 | 462/619 batches | 17.77ms/ batch | BCE: 0.0263 | Accuracy: 95.33% |
# Epoch 15 | 616/619 batches | 17.75ms/ batch | BCE: 0.0254 | Accuracy: 95.38% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time: 11.01s | BCE: 0.0254 | Accuracy: 95.38% |
# End of validation epoch  15 | time:  0.57s | BCE: 0.1062 | Accuracy: 84.62% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 | 154/619 batches | 17.93ms/ batch | BCE: 0.0213 | Accuracy: 95.94% |
# Epoch 16 | 308/619 batches | 17.84ms/ batch | BCE: 0.0226 | Accuracy: 95.78% |
# Epoch 16 | 462/619 batches | 17.75ms/ batch | BCE: 0.0238 | Accuracy: 95.66% |
# Epoch 16 | 616/619 batches | 17.70ms/ batch | BCE: 0.0233 | Accuracy: 95.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time: 10.97s | BCE: 0.0233 | Accuracy: 95.85% |
# End of validation epoch  16 | time:  0.63s | BCE: 0.0578 | Accuracy: 90.21% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 | 154/619 batches | 17.82ms/ batch | BCE: 0.0234 | Accuracy: 95.58% |
# Epoch 17 | 308/619 batches | 17.71ms/ batch | BCE: 0.0213 | Accuracy: 96.16% |
# Epoch 17 | 462/619 batches | 17.69ms/ batch | BCE: 0.0209 | Accuracy: 96.28% |
# Epoch 17 | 616/619 batches | 17.67ms/ batch | BCE: 0.0207 | Accuracy: 96.30% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time: 10.96s | BCE: 0.0207 | Accuracy: 96.29% |
# End of validation epoch  17 | time:  0.58s | BCE: 0.2611 | Accuracy: 68.61% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 | 154/619 batches | 18.12ms/ batch | BCE: 0.0175 | Accuracy: 96.55% |
# Epoch 18 | 308/619 batches | 17.92ms/ batch | BCE: 0.0166 | Accuracy: 96.85% |
# Epoch 18 | 462/619 batches | 17.83ms/ batch | BCE: 0.0168 | Accuracy: 96.94% |
# Epoch 18 | 616/619 batches | 17.76ms/ batch | BCE: 0.0173 | Accuracy: 96.99% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time: 11.01s | BCE: 0.0173 | Accuracy: 96.99% |
# End of validation epoch  18 | time:  0.60s | BCE: 0.0943 | Accuracy: 86.30% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 | 154/619 batches | 17.84ms/ batch | BCE: 0.0170 | Accuracy: 97.12% |
# Epoch 19 | 308/619 batches | 17.73ms/ batch | BCE: 0.0165 | Accuracy: 97.24% |
# Epoch 19 | 462/619 batches | 17.69ms/ batch | BCE: 0.0162 | Accuracy: 97.24% |
# Epoch 19 | 616/619 batches | 17.66ms/ batch | BCE: 0.0165 | Accuracy: 97.19% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time: 10.95s | BCE: 0.0167 | Accuracy: 97.15% |
# End of validation epoch  19 | time:  0.57s | BCE: 0.1511 | Accuracy: 80.66% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 | 154/619 batches | 18.00ms/ batch | BCE: 0.0148 | Accuracy: 97.61% |
# Epoch 20 | 308/619 batches | 17.83ms/ batch | BCE: 0.0153 | Accuracy: 97.52% |
# Epoch 20 | 462/619 batches | 17.78ms/ batch | BCE: 0.0154 | Accuracy: 97.52% |
# Epoch 20 | 616/619 batches | 17.76ms/ batch | BCE: 0.0158 | Accuracy: 97.41% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time: 11.01s | BCE: 0.0160 | Accuracy: 97.38% |
# End of validation epoch  20 | time:  0.57s | BCE: 0.4315 | Accuracy: 63.00% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
# visualization
plt.figure()
plt.plot(t_accu, c='b', label='Training set accuracy')
plt.plot(v_accu, c='r', label='Validation set accuracy')
plt.title('Accuracy vs Epochs / pure CNN Model')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Model on Test Set

# %%
M_model.load_state_dict(torch.load(Para.MODEL_SAVE_PATH_1A))
validate_test(M_model, 0, test=True)
# Out:
# End of Test | time:  0.57s | BCE: 0.0563 | Accuracy: 90.46% |
# ---------------------------------------------------------------------------------------------------
# (0.056254354842866845, 0.9046474358974359)
