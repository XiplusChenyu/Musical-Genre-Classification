# %%
import time
import numpy as np

from basic_model import M_model
import torch
from torch import optim
from util import bce_loss, accuracy_function
from Paras import Para

from data_loader import train_loader, validation_loader, test_loader

Para.dataset_len = len(train_loader)
Para.log_step = len(train_loader) // 4

optimizer = torch.optim.RMSprop(M_model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)


def train(model, epoch, versatile=True):
    start_time = time.time()
    model = model.train()
    train_loss = 0.
    accuracy = 0.
    batch_num = len(train_loader)
    _index = 0

    for _index, data in enumerate(train_loader):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        optimizer.zero_grad()
        predicted = model(spec_input)

        loss_value = bce_loss(predicted, target)
        accuracy_value = accuracy_function(predicted, target)

        loss_value.backward()
        optimizer.step()

        train_loss += loss_value.data.item()
        accuracy += accuracy_value

        if versatile:
            if (_index + 1) % Para.log_step == 0:
                elapsed = time.time() - start_time
                print('Epoch{:3d} | {:3d}/{:3d} batches | {:5.2f}ms/ batch | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
                      .format(epoch, _index + 1, batch_num,
                              elapsed * 1000 / (_index + 1),
                              train_loss / (_index + 1),
                              accuracy * 100 / (_index + 1)))

    train_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('-' * 99)
    print('End of training epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  train_loss, accuracy * 100))

    return train_loss, accuracy


def validate_test(model, epoch, test=False):
    start_time = time.time()
    model = model.eval()
    v_loss = 0.
    accuracy = 0.
    data_loader_use = validation_loader if not test else test_loader
    _index = 0
    for _index, data in enumerate(data_loader_use):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        with torch.no_grad():

            predicted = model(spec_input)

            loss_value = bce_loss(predicted, target)
            accuracy_value = accuracy_function(predicted, target)

            v_loss += loss_value.data.item()
            accuracy += accuracy_value

    v_loss /= (_index + 1)
    accuracy /= (_index + 1)

    if not test:
        print('End of validation epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format(epoch, (time.time() - start_time),
                v_loss, accuracy * 100))
    else:
        print('End of Test | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format((time.time() - start_time),
                v_loss, accuracy * 100))
    print('-' * 99)

    return v_loss, accuracy

# %% [markdown]
# # Train the model here

# %%
Para.cuda
# Out:
# True

# %%
t_loss, t_accu, v_loss, v_accu = [], [], [], []
decay_cnt = 0

for epoch in range(1, Para.epoch_num + 1):
    if Para.cuda:
        M_model.cuda()

    train_loss, train_accuracy = train(M_model, epoch)
    validation_loss, validation_accuracy = validate_test(M_model, epoch, test=False)

    t_loss.append(train_loss)
    t_accu.append(train_accuracy)

    v_loss.append(validation_loss)
    v_accu.append(validation_accuracy)

    # use accuracy to find the best model
    if np.max(t_accu) == t_accu[-1]:
        print('***Found Best Training Model***')
    if np.max(v_accu) == v_accu[-1]:
        with open(Para.MODEL_SAVE_PATH_1, 'wb') as f:
            torch.save(M_model.cpu().state_dict(), f)
            print('***Best Validation Model Found and Saved***')

    print('-' * 99)

    # Use BCE loss value for learning rate scheduling
    decay_cnt += 1

    if np.min(t_loss) not in t_loss[-3:] and decay_cnt > 2:
        scheduler.step()
        decay_cnt = 0
        print('***Learning rate decreased***')
        print('-' * 99)
# Out:
# Epoch  1 |  87/350 batches | 354.43ms/ batch | BCE: 0.2970 | Accuracy: 24.35% |
# Epoch  1 | 174/350 batches | 333.07ms/ batch | BCE: 0.2788 | Accuracy: 30.10% |
# Epoch  1 | 261/350 batches | 304.58ms/ batch | BCE: 0.2685 | Accuracy: 32.85% |
# Epoch  1 | 348/350 batches | 272.98ms/ batch | BCE: 0.2618 | Accuracy: 35.11% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 95.17s | BCE: 0.2615 | Accuracy: 35.23% |
# End of validation epoch   1 | time:  0.91s | BCE: 0.2113 | Accuracy: 50.52% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 |  87/350 batches | 18.18ms/ batch | BCE: 0.2271 | Accuracy: 45.91% |
# Epoch  2 | 174/350 batches | 17.88ms/ batch | BCE: 0.2247 | Accuracy: 46.62% |
# Epoch  2 | 261/350 batches | 17.86ms/ batch | BCE: 0.2200 | Accuracy: 48.54% |
# Epoch  2 | 348/350 batches | 17.77ms/ batch | BCE: 0.2147 | Accuracy: 49.77% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time:  6.24s | BCE: 0.2148 | Accuracy: 49.77% |
# End of validation epoch   2 | time:  0.34s | BCE: 0.1769 | Accuracy: 62.17% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 |  87/350 batches | 18.10ms/ batch | BCE: 0.1906 | Accuracy: 56.61% |
# Epoch  3 | 174/350 batches | 17.86ms/ batch | BCE: 0.1880 | Accuracy: 58.62% |
# Epoch  3 | 261/350 batches | 17.72ms/ batch | BCE: 0.1880 | Accuracy: 59.15% |
# Epoch  3 | 348/350 batches | 17.65ms/ batch | BCE: 0.1836 | Accuracy: 60.38% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time:  6.20s | BCE: 0.1836 | Accuracy: 60.43% |
# End of validation epoch   3 | time:  0.37s | BCE: 0.1443 | Accuracy: 69.74% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 |  87/350 batches | 18.09ms/ batch | BCE: 0.1564 | Accuracy: 66.81% |
# Epoch  4 | 174/350 batches | 18.03ms/ batch | BCE: 0.1561 | Accuracy: 66.99% |
# Epoch  4 | 261/350 batches | 18.41ms/ batch | BCE: 0.1545 | Accuracy: 67.55% |
# Epoch  4 | 348/350 batches | 18.65ms/ batch | BCE: 0.1545 | Accuracy: 67.85% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time:  6.55s | BCE: 0.1547 | Accuracy: 67.79% |
# End of validation epoch   4 | time:  0.46s | BCE: 0.1331 | Accuracy: 71.26% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 |  87/350 batches | 37.61ms/ batch | BCE: 0.1435 | Accuracy: 70.47% |
# Epoch  5 | 174/350 batches | 37.31ms/ batch | BCE: 0.1410 | Accuracy: 71.05% |
# Epoch  5 | 261/350 batches | 37.22ms/ batch | BCE: 0.1380 | Accuracy: 71.82% |
# Epoch  5 | 348/350 batches | 37.17ms/ batch | BCE: 0.1351 | Accuracy: 72.67% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time: 13.03s | BCE: 0.1349 | Accuracy: 72.70% |
# End of validation epoch   5 | time:  0.58s | BCE: 0.1362 | Accuracy: 71.26% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 |  87/350 batches | 37.55ms/ batch | BCE: 0.1257 | Accuracy: 74.35% |
# Epoch  6 | 174/350 batches | 37.29ms/ batch | BCE: 0.1224 | Accuracy: 75.32% |
# Epoch  6 | 261/350 batches | 36.11ms/ batch | BCE: 0.1216 | Accuracy: 75.26% |
# Epoch  6 | 348/350 batches | 36.16ms/ batch | BCE: 0.1187 | Accuracy: 75.72% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time: 12.68s | BCE: 0.1186 | Accuracy: 75.75% |
# End of validation epoch   6 | time:  0.57s | BCE: 0.1339 | Accuracy: 72.44% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 |  87/350 batches | 37.62ms/ batch | BCE: 0.1061 | Accuracy: 79.60% |
# Epoch  7 | 174/350 batches | 37.33ms/ batch | BCE: 0.1058 | Accuracy: 78.81% |
# Epoch  7 | 261/350 batches | 37.23ms/ batch | BCE: 0.1041 | Accuracy: 79.38% |
# Epoch  7 | 348/350 batches | 37.19ms/ batch | BCE: 0.1037 | Accuracy: 79.54% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time: 13.04s | BCE: 0.1038 | Accuracy: 79.52% |
# End of validation epoch   7 | time:  0.57s | BCE: 0.1128 | Accuracy: 75.99% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 |  87/350 batches | 37.54ms/ batch | BCE: 0.0972 | Accuracy: 80.96% |
# Epoch  8 | 174/350 batches | 35.17ms/ batch | BCE: 0.0979 | Accuracy: 80.53% |
# Epoch  8 | 261/350 batches | 35.78ms/ batch | BCE: 0.0952 | Accuracy: 81.25% |
# Epoch  8 | 348/350 batches | 36.09ms/ batch | BCE: 0.0947 | Accuracy: 81.41% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time: 12.66s | BCE: 0.0944 | Accuracy: 81.45% |
# End of validation epoch   8 | time:  0.57s | BCE: 0.1551 | Accuracy: 68.84% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 |  87/350 batches | 37.51ms/ batch | BCE: 0.0815 | Accuracy: 84.84% |
# Epoch  9 | 174/350 batches | 37.29ms/ batch | BCE: 0.0807 | Accuracy: 84.99% |
# Epoch  9 | 261/350 batches | 37.21ms/ batch | BCE: 0.0800 | Accuracy: 85.03% |
# Epoch  9 | 348/350 batches | 37.17ms/ batch | BCE: 0.0802 | Accuracy: 84.82% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time: 13.03s | BCE: 0.0803 | Accuracy: 84.79% |
# End of validation epoch   9 | time:  0.57s | BCE: 0.1086 | Accuracy: 76.42% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 |  87/350 batches | 34.88ms/ batch | BCE: 0.0701 | Accuracy: 86.28% |
# Epoch 10 | 174/350 batches | 35.96ms/ batch | BCE: 0.0733 | Accuracy: 85.67% |
# Epoch 10 | 261/350 batches | 36.31ms/ batch | BCE: 0.0709 | Accuracy: 86.23% |
# Epoch 10 | 348/350 batches | 36.49ms/ batch | BCE: 0.0704 | Accuracy: 86.21% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time: 12.80s | BCE: 0.0705 | Accuracy: 86.21% |
# End of validation epoch  10 | time:  0.58s | BCE: 0.2117 | Accuracy: 61.93% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 |  87/350 batches | 37.53ms/ batch | BCE: 0.0579 | Accuracy: 88.72% |
# Epoch 11 | 174/350 batches | 37.29ms/ batch | BCE: 0.0619 | Accuracy: 87.72% |
# Epoch 11 | 261/350 batches | 37.20ms/ batch | BCE: 0.0628 | Accuracy: 87.45% |
# Epoch 11 | 348/350 batches | 36.31ms/ batch | BCE: 0.0630 | Accuracy: 87.79% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time: 12.70s | BCE: 0.0628 | Accuracy: 87.80% |
# End of validation epoch  11 | time:  0.56s | BCE: 0.1998 | Accuracy: 64.58% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 |  87/350 batches | 37.54ms/ batch | BCE: 0.0487 | Accuracy: 91.45% |
# Epoch 12 | 174/350 batches | 37.29ms/ batch | BCE: 0.0480 | Accuracy: 91.27% |
# Epoch 12 | 261/350 batches | 37.21ms/ batch | BCE: 0.0510 | Accuracy: 90.47% |
# Epoch 12 | 348/350 batches | 37.17ms/ batch | BCE: 0.0524 | Accuracy: 90.09% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time: 13.03s | BCE: 0.0525 | Accuracy: 90.07% |
# End of validation epoch  12 | time:  0.57s | BCE: 0.1423 | Accuracy: 74.05% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 |  87/350 batches | 37.58ms/ batch | BCE: 0.0437 | Accuracy: 91.81% |
# Epoch 13 | 174/350 batches | 37.31ms/ batch | BCE: 0.0445 | Accuracy: 91.70% |
# Epoch 13 | 261/350 batches | 36.25ms/ batch | BCE: 0.0448 | Accuracy: 91.83% |
# Epoch 13 | 348/350 batches | 36.07ms/ batch | BCE: 0.0457 | Accuracy: 91.81% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time: 12.65s | BCE: 0.0457 | Accuracy: 91.82% |
# End of validation epoch  13 | time:  0.58s | BCE: 0.0665 | Accuracy: 86.84% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 |  87/350 batches | 37.59ms/ batch | BCE: 0.0385 | Accuracy: 93.25% |
# Epoch 14 | 174/350 batches | 37.32ms/ batch | BCE: 0.0374 | Accuracy: 93.32% |
# Epoch 14 | 261/350 batches | 37.23ms/ batch | BCE: 0.0401 | Accuracy: 92.77% |
# Epoch 14 | 348/350 batches | 37.18ms/ batch | BCE: 0.0399 | Accuracy: 92.74% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time: 13.04s | BCE: 0.0397 | Accuracy: 92.79% |
# End of validation epoch  14 | time:  0.57s | BCE: 0.1053 | Accuracy: 79.78% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 |  87/350 batches | 37.66ms/ batch | BCE: 0.0354 | Accuracy: 93.82% |
# Epoch 15 | 174/350 batches | 35.75ms/ batch | BCE: 0.0351 | Accuracy: 94.00% |
# Epoch 15 | 261/350 batches | 36.18ms/ batch | BCE: 0.0342 | Accuracy: 94.09% |
# Epoch 15 | 348/350 batches | 36.40ms/ batch | BCE: 0.0376 | Accuracy: 93.61% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time: 12.77s | BCE: 0.0375 | Accuracy: 93.64% |
# End of validation epoch  15 | time:  0.57s | BCE: 0.0712 | Accuracy: 86.22% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 |  87/350 batches | 37.54ms/ batch | BCE: 0.0249 | Accuracy: 96.12% |
# Epoch 16 | 174/350 batches | 37.29ms/ batch | BCE: 0.0288 | Accuracy: 95.15% |
# Epoch 16 | 261/350 batches | 37.20ms/ batch | BCE: 0.0304 | Accuracy: 94.76% |
# Epoch 16 | 348/350 batches | 37.15ms/ batch | BCE: 0.0303 | Accuracy: 94.65% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time: 13.03s | BCE: 0.0304 | Accuracy: 94.64% |
# End of validation epoch  16 | time:  0.58s | BCE: 0.0839 | Accuracy: 82.86% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 |  87/350 batches | 34.81ms/ batch | BCE: 0.0276 | Accuracy: 94.83% |
# Epoch 17 | 174/350 batches | 35.93ms/ batch | BCE: 0.0265 | Accuracy: 94.94% |
# Epoch 17 | 261/350 batches | 36.30ms/ batch | BCE: 0.0296 | Accuracy: 94.54% |
# Epoch 17 | 348/350 batches | 36.49ms/ batch | BCE: 0.0285 | Accuracy: 94.77% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time: 12.80s | BCE: 0.0284 | Accuracy: 94.79% |
# End of validation epoch  17 | time:  0.57s | BCE: 0.0954 | Accuracy: 84.14% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 |  87/350 batches | 37.60ms/ batch | BCE: 0.0125 | Accuracy: 97.84% |
# Epoch 18 | 174/350 batches | 37.33ms/ batch | BCE: 0.0248 | Accuracy: 95.87% |
# Epoch 18 | 261/350 batches | 37.24ms/ batch | BCE: 0.0244 | Accuracy: 95.88% |
# Epoch 18 | 348/350 batches | 36.80ms/ batch | BCE: 0.0238 | Accuracy: 95.94% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time: 12.90s | BCE: 0.0238 | Accuracy: 95.93% |
# End of validation epoch  18 | time:  0.51s | BCE: 0.1196 | Accuracy: 80.02% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 |  87/350 batches | 37.61ms/ batch | BCE: 0.0221 | Accuracy: 96.34% |
# Epoch 19 | 174/350 batches | 37.33ms/ batch | BCE: 0.0215 | Accuracy: 96.52% |
# Epoch 19 | 261/350 batches | 37.24ms/ batch | BCE: 0.0217 | Accuracy: 96.24% |
# Epoch 19 | 348/350 batches | 37.19ms/ batch | BCE: 0.0216 | Accuracy: 96.23% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time: 13.04s | BCE: 0.0215 | Accuracy: 96.25% |
# End of validation epoch  19 | time:  0.57s | BCE: 0.1028 | Accuracy: 83.57% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 |  87/350 batches | 37.67ms/ batch | BCE: 0.0209 | Accuracy: 96.91% |
# Epoch 20 | 174/350 batches | 37.36ms/ batch | BCE: 0.0209 | Accuracy: 96.41% |
# Epoch 20 | 261/350 batches | 36.65ms/ batch | BCE: 0.0224 | Accuracy: 96.17% |
# Epoch 20 | 348/350 batches | 36.06ms/ batch | BCE: 0.0205 | Accuracy: 96.53% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time: 12.65s | BCE: 0.0204 | Accuracy: 96.55% |
# End of validation epoch  20 | time:  0.57s | BCE: 0.1024 | Accuracy: 84.47% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
# visualization
plt.figure()
plt.plot(t_accu, c='b', label='Training set accuracy')
plt.plot(v_accu, c='r', label='Validation set accuracy')
plt.title('Accuracy vs Epochs / pure CNN Model')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Model on Test Set

# %%
M_model.load_state_dict(torch.load(Para.MODEL_SAVE_PATH_1))
validate_test(M_model, 0, test=True)
# Out:
# End of Test | time:  0.83s | BCE: 0.0763 | Accuracy: 86.17% |
# ---------------------------------------------------------------------------------------------------
# (0.07630310763223944, 0.8617424242424242)
