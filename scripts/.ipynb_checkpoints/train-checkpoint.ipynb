# %%
import time
import numpy as np

from model import M_model
import torch
from torch import optim
from util import bce_loss, accuracy_function
from Paras import Para

from data_loader import train_loader, validation_loader, test_loader

Para.dataset_len = len(train_loader)
Para.log_step = len(train_loader) // 4

optimizer = torch.optim.RMSprop(M_model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)


def train(model, epoch, versatile=True):
    start_time = time.time()
    model = model.train()
    train_loss = 0.
    accuracy = 0.
    batch_num = len(train_loader)
    _index = 0

    for _index, data in enumerate(train_loader):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        optimizer.zero_grad()
        predicted = model(spec_input)

        loss_value = bce_loss(predicted, target)
        accuracy_value = accuracy_function(predicted, target)

        loss_value.backward()
        optimizer.step()

        train_loss += loss_value.data.item()
        accuracy += accuracy_value

        if versatile:
            if (_index + 1) % Para.log_step == 0:
                elapsed = time.time() - start_time
                print('Epoch{:3d} | {:3d}/{:3d} batches | {:5.2f}ms/ batch | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
                      .format(epoch, _index + 1, batch_num,
                              elapsed * 1000 / (_index + 1),
                              train_loss / (_index + 1),
                              accuracy * 100 / (_index + 1)))

    train_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('-' * 99)
    print('End of training epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  train_loss, accuracy * 100))

    return train_loss, accuracy


def validate_test(model, epoch, test=False):
    start_time = time.time()
    model = model.eval()
    v_loss = 0.
    accuracy = 0.
    data_loader_use = validation_loader if not test else test_loader
    _index = 0
    for _index, data in enumerate(data_loader_use):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        with torch.no_grad():

            predicted = model(spec_input)

            loss_value = bce_loss(predicted, target)
            accuracy_value = accuracy_function(predicted, target)

            v_loss += loss_value.data.item()
            accuracy += accuracy_value

    v_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('End of validation epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  v_loss, accuracy * 100))
    print('-' * 99)

    return v_loss, accuracy

# %% [markdown]
# # Train the model here

# %%
Para.cuda
# Out:
# True

# %%
t_loss, t_accu, v_loss, v_accu = [], [], [], []
decay_cnt = 0

for epoch in range(1, Para.epoch_num + 1):
    if Para.cuda:
        M_model.cuda()

    train_loss, train_accuracy = train(M_model, epoch)
    validation_loss, validation_accuracy = validate_test(M_model, epoch, test=False)

    t_loss.append(train_loss)
    t_accu.append(train_accuracy)

    v_loss.append(validation_loss)
    v_accu.append(validation_accuracy)

    # use accuracy to find the best model
    if np.max(t_accu) == t_accu[-1]:
        print('***Found Best Training Model***')
    if np.max(v_accu) == v_accu[-1]:
        with open(Para.MODEL_SAVE_PATH_1, 'wb') as f:
            torch.save(M_model.cpu().state_dict(), f)
            print('***Best Validation Model Found and Saved***')

    print('-' * 99)

    # Use BCE loss value for learning rate scheduling
    decay_cnt += 1

    if np.min(t_loss) not in t_loss[-3:] and decay_cnt > 2:
        scheduler.step()
        decay_cnt = 0
        print('***Learning rate decreased***')
        print('-' * 99)
# Out:
# Epoch  1 |  87/350 batches | 31.25ms/ batch | BCE: 0.2972 | Accuracy: 24.50% |
# Epoch  1 | 174/350 batches | 24.42ms/ batch | BCE: 0.2798 | Accuracy: 29.99% |
# Epoch  1 | 261/350 batches | 22.15ms/ batch | BCE: 0.2690 | Accuracy: 32.64% |
# Epoch  1 | 348/350 batches | 21.05ms/ batch | BCE: 0.2623 | Accuracy: 34.57% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time:  7.38s | BCE: 0.2621 | Accuracy: 34.68% |
# End of validation epoch   1 | time:  0.34s | BCE: 0.2088 | Accuracy: 52.79% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 |  87/350 batches | 18.20ms/ batch | BCE: 0.2279 | Accuracy: 46.41% |
# Epoch  2 | 174/350 batches | 17.91ms/ batch | BCE: 0.2256 | Accuracy: 46.95% |
# Epoch  2 | 261/350 batches | 17.82ms/ batch | BCE: 0.2209 | Accuracy: 48.54% |
# Epoch  2 | 348/350 batches | 17.78ms/ batch | BCE: 0.2159 | Accuracy: 49.77% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time:  6.25s | BCE: 0.2159 | Accuracy: 49.75% |
# End of validation epoch   2 | time:  0.35s | BCE: 0.1743 | Accuracy: 63.45% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 |  87/350 batches | 18.27ms/ batch | BCE: 0.1907 | Accuracy: 56.90% |
# Epoch  3 | 174/350 batches | 17.99ms/ batch | BCE: 0.1877 | Accuracy: 58.33% |
# Epoch  3 | 261/350 batches | 17.89ms/ batch | BCE: 0.1884 | Accuracy: 58.62% |
# Epoch  3 | 348/350 batches | 17.83ms/ batch | BCE: 0.1842 | Accuracy: 59.95% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time:  6.26s | BCE: 0.1842 | Accuracy: 59.96% |
# End of validation epoch   3 | time:  0.34s | BCE: 0.1449 | Accuracy: 69.65% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 |  87/350 batches | 18.18ms/ batch | BCE: 0.1597 | Accuracy: 66.31% |
# Epoch  4 | 174/350 batches | 17.93ms/ batch | BCE: 0.1574 | Accuracy: 66.74% |
# Epoch  4 | 261/350 batches | 17.85ms/ batch | BCE: 0.1554 | Accuracy: 67.36% |
# Epoch  4 | 348/350 batches | 17.80ms/ batch | BCE: 0.1548 | Accuracy: 67.76% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time:  6.25s | BCE: 0.1551 | Accuracy: 67.71% |
# End of validation epoch   4 | time:  0.34s | BCE: 0.1296 | Accuracy: 72.02% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 |  87/350 batches | 18.19ms/ batch | BCE: 0.1440 | Accuracy: 70.76% |
# Epoch  5 | 174/350 batches | 17.92ms/ batch | BCE: 0.1406 | Accuracy: 70.98% |
# Epoch  5 | 261/350 batches | 17.82ms/ batch | BCE: 0.1369 | Accuracy: 71.74% |
# Epoch  5 | 348/350 batches | 17.80ms/ batch | BCE: 0.1345 | Accuracy: 72.54% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time:  6.25s | BCE: 0.1343 | Accuracy: 72.62% |
# End of validation epoch   5 | time:  0.39s | BCE: 0.1323 | Accuracy: 71.92% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 |  87/350 batches | 18.09ms/ batch | BCE: 0.1266 | Accuracy: 74.64% |
# Epoch  6 | 174/350 batches | 17.82ms/ batch | BCE: 0.1220 | Accuracy: 76.01% |
# Epoch  6 | 261/350 batches | 17.72ms/ batch | BCE: 0.1212 | Accuracy: 75.96% |
# Epoch  6 | 348/350 batches | 17.68ms/ batch | BCE: 0.1181 | Accuracy: 76.47% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time:  6.21s | BCE: 0.1180 | Accuracy: 76.48% |
# End of validation epoch   6 | time:  0.39s | BCE: 0.1641 | Accuracy: 65.86% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 |  87/350 batches | 18.15ms/ batch | BCE: 0.1059 | Accuracy: 78.66% |
# Epoch  7 | 174/350 batches | 17.88ms/ batch | BCE: 0.1044 | Accuracy: 78.95% |
# Epoch  7 | 261/350 batches | 17.78ms/ batch | BCE: 0.1036 | Accuracy: 79.21% |
# Epoch  7 | 348/350 batches | 17.72ms/ batch | BCE: 0.1036 | Accuracy: 78.99% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time:  6.23s | BCE: 0.1037 | Accuracy: 78.96% |
# End of validation epoch   7 | time:  0.37s | BCE: 0.1144 | Accuracy: 75.38% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 |  87/350 batches | 18.16ms/ batch | BCE: 0.0970 | Accuracy: 81.39% |
# Epoch  8 | 174/350 batches | 17.86ms/ batch | BCE: 0.0959 | Accuracy: 81.21% |
# Epoch  8 | 261/350 batches | 17.79ms/ batch | BCE: 0.0941 | Accuracy: 81.99% |
# Epoch  8 | 348/350 batches | 17.76ms/ batch | BCE: 0.0935 | Accuracy: 82.11% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time:  6.24s | BCE: 0.0933 | Accuracy: 82.12% |
# End of validation epoch   8 | time:  0.35s | BCE: 0.1591 | Accuracy: 67.33% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 |  87/350 batches | 18.21ms/ batch | BCE: 0.0814 | Accuracy: 84.99% |
# Epoch  9 | 174/350 batches | 17.91ms/ batch | BCE: 0.0818 | Accuracy: 85.06% |
# Epoch  9 | 261/350 batches | 17.82ms/ batch | BCE: 0.0806 | Accuracy: 84.89% |
# Epoch  9 | 348/350 batches | 17.73ms/ batch | BCE: 0.0813 | Accuracy: 84.66% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time:  6.23s | BCE: 0.0813 | Accuracy: 84.62% |
# End of validation epoch   9 | time:  0.36s | BCE: 0.1202 | Accuracy: 75.47% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 |  87/350 batches | 18.36ms/ batch | BCE: 0.0696 | Accuracy: 86.71% |
# Epoch 10 | 174/350 batches | 18.06ms/ batch | BCE: 0.0711 | Accuracy: 86.28% |
# Epoch 10 | 261/350 batches | 17.96ms/ batch | BCE: 0.0698 | Accuracy: 86.93% |
# Epoch 10 | 348/350 batches | 17.90ms/ batch | BCE: 0.0702 | Accuracy: 86.71% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time:  6.29s | BCE: 0.0702 | Accuracy: 86.70% |
# End of validation epoch  10 | time:  0.34s | BCE: 0.1080 | Accuracy: 77.84% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 |  87/350 batches | 18.23ms/ batch | BCE: 0.0584 | Accuracy: 89.15% |
# Epoch 11 | 174/350 batches | 17.96ms/ batch | BCE: 0.0601 | Accuracy: 88.72% |
# Epoch 11 | 261/350 batches | 17.83ms/ batch | BCE: 0.0611 | Accuracy: 88.24% |
# Epoch 11 | 348/350 batches | 17.77ms/ batch | BCE: 0.0617 | Accuracy: 87.95% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time:  6.24s | BCE: 0.0615 | Accuracy: 87.98% |
# End of validation epoch  11 | time:  0.34s | BCE: 0.1325 | Accuracy: 75.28% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 |  87/350 batches | 18.22ms/ batch | BCE: 0.0472 | Accuracy: 91.81% |
# Epoch 12 | 174/350 batches | 17.99ms/ batch | BCE: 0.0490 | Accuracy: 90.95% |
# Epoch 12 | 261/350 batches | 17.88ms/ batch | BCE: 0.0507 | Accuracy: 90.33% |
# Epoch 12 | 348/350 batches | 17.77ms/ batch | BCE: 0.0523 | Accuracy: 89.96% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time:  6.24s | BCE: 0.0524 | Accuracy: 89.95% |
# End of validation epoch  12 | time:  0.32s | BCE: 0.1083 | Accuracy: 78.98% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 |  87/350 batches | 18.20ms/ batch | BCE: 0.0407 | Accuracy: 92.31% |
# Epoch 13 | 174/350 batches | 17.95ms/ batch | BCE: 0.0427 | Accuracy: 91.63% |
# Epoch 13 | 261/350 batches | 17.84ms/ batch | BCE: 0.0448 | Accuracy: 91.31% |
# Epoch 13 | 348/350 batches | 17.77ms/ batch | BCE: 0.0451 | Accuracy: 91.24% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time:  6.24s | BCE: 0.0450 | Accuracy: 91.23% |
# End of validation epoch  13 | time:  0.35s | BCE: 0.0795 | Accuracy: 84.52% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 |  87/350 batches | 18.06ms/ batch | BCE: 0.0386 | Accuracy: 92.96% |
# Epoch 14 | 174/350 batches | 17.93ms/ batch | BCE: 0.0377 | Accuracy: 93.32% |
# Epoch 14 | 261/350 batches | 17.86ms/ batch | BCE: 0.0379 | Accuracy: 93.08% |
# Epoch 14 | 348/350 batches | 17.84ms/ batch | BCE: 0.0382 | Accuracy: 93.01% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time:  6.26s | BCE: 0.0381 | Accuracy: 93.05% |
# End of validation epoch  14 | time:  0.35s | BCE: 0.0746 | Accuracy: 86.17% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 |  87/350 batches | 18.14ms/ batch | BCE: 0.0384 | Accuracy: 91.74% |
# Epoch 15 | 174/350 batches | 17.90ms/ batch | BCE: 0.0335 | Accuracy: 93.25% |
# Epoch 15 | 261/350 batches | 17.82ms/ batch | BCE: 0.0331 | Accuracy: 93.41% |
# Epoch 15 | 348/350 batches | 17.78ms/ batch | BCE: 0.0357 | Accuracy: 93.00% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time:  6.25s | BCE: 0.0355 | Accuracy: 93.02% |
# End of validation epoch  15 | time:  0.39s | BCE: 0.0817 | Accuracy: 85.80% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# Epoch 16 |  87/350 batches | 18.28ms/ batch | BCE: 0.0254 | Accuracy: 94.97% |
# Epoch 16 | 174/350 batches | 18.01ms/ batch | BCE: 0.0288 | Accuracy: 94.50% |
# Epoch 16 | 261/350 batches | 17.89ms/ batch | BCE: 0.0310 | Accuracy: 94.11% |
# Epoch 16 | 348/350 batches | 17.83ms/ batch | BCE: 0.0305 | Accuracy: 94.36% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time:  6.26s | BCE: 0.0306 | Accuracy: 94.32% |
# End of validation epoch  16 | time:  0.33s | BCE: 0.0810 | Accuracy: 84.33% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 |  87/350 batches | 18.16ms/ batch | BCE: 0.0268 | Accuracy: 95.26% |
# Epoch 17 | 174/350 batches | 18.00ms/ batch | BCE: 0.0250 | Accuracy: 95.73% |
# Epoch 17 | 261/350 batches | 17.91ms/ batch | BCE: 0.0278 | Accuracy: 95.16% |
# Epoch 17 | 348/350 batches | 17.85ms/ batch | BCE: 0.0285 | Accuracy: 94.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time:  6.27s | BCE: 0.0284 | Accuracy: 94.84% |
# End of validation epoch  17 | time:  0.35s | BCE: 0.1763 | Accuracy: 73.20% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 |  87/350 batches | 18.20ms/ batch | BCE: 0.0219 | Accuracy: 96.19% |
# Epoch 18 | 174/350 batches | 17.93ms/ batch | BCE: 0.0239 | Accuracy: 95.58% |
# Epoch 18 | 261/350 batches | 17.85ms/ batch | BCE: 0.0251 | Accuracy: 95.35% |
# Epoch 18 | 348/350 batches | 17.79ms/ batch | BCE: 0.0240 | Accuracy: 95.56% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time:  6.25s | BCE: 0.0240 | Accuracy: 95.55% |
# End of validation epoch  18 | time:  0.40s | BCE: 0.1640 | Accuracy: 74.34% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 |  87/350 batches | 18.12ms/ batch | BCE: 0.0216 | Accuracy: 96.26% |
# Epoch 19 | 174/350 batches | 17.81ms/ batch | BCE: 0.0226 | Accuracy: 96.30% |
# Epoch 19 | 261/350 batches | 17.71ms/ batch | BCE: 0.0218 | Accuracy: 96.29% |
# Epoch 19 | 348/350 batches | 17.66ms/ batch | BCE: 0.0209 | Accuracy: 96.30% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time:  6.21s | BCE: 0.0210 | Accuracy: 96.30% |
# End of validation epoch  19 | time:  0.37s | BCE: 0.1242 | Accuracy: 82.53% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 |  87/350 batches | 18.12ms/ batch | BCE: 0.0198 | Accuracy: 96.41% |
# Epoch 20 | 174/350 batches | 17.88ms/ batch | BCE: 0.0212 | Accuracy: 96.34% |
# Epoch 20 | 261/350 batches | 17.76ms/ batch | BCE: 0.0210 | Accuracy: 96.22% |
# Epoch 20 | 348/350 batches | 17.72ms/ batch | BCE: 0.0201 | Accuracy: 96.46% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time:  6.22s | BCE: 0.0199 | Accuracy: 96.48% |
# End of validation epoch  20 | time:  0.36s | BCE: 0.0873 | Accuracy: 84.90% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
