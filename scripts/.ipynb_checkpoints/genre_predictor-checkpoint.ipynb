# %% [markdown]
# # Music Predictor
# Using this file to predict the genre of a given music file

# %%
from music_dealer import MusicDealer
from models import CnnModel, CrnnLongModel, CrnnModel 
import json
from Paras import Para
import os

WEIGHT_PATH = "../model/"
cnn_dealer = MusicDealer(WEIGHT_PATH + "CnnModel.pt", CnnModel())
crnn_dealer = MusicDealer(WEIGHT_PATH + "CrnnModel.pt", CrnnModel())
lcrnn_dealer = MusicDealer(WEIGHT_PATH + "CrnnLongModel.pt", CrnnLongModel())

# %% [markdown]
# # Sample Music  Paths

# %%
data_path = '../sample_music'
genre_path_dict = dict()
label_dict = dict()
for (dirpath, dirnames, filenames) in os.walk(data_path):
    if dirnames:
        for idx, genre in enumerate(dirnames):
            genre_path_dict[genre] = list()
            label_dict[genre] = idx
        continue
    else:
        genre = dirpath.split('/')[-1]
        for au_file in filenames:
            if 'mp3' in au_file:
                current_path = dirpath + '/' + au_file
                genre_path_dict[genre].append(current_path)

total_file = sum([len(genre_path_dict[genre]) for genre in genre_path_dict])
total_file, label_dict
# Out:
# (30,
#  {'pop': 0,
#   'metal': 1,
#   'disco': 2,
#   'blues': 3,
#   'reggae': 4,
#   'classical': 5,
#   'rock': 6,
#   'hiphop': 7,
#   'country': 8,
#   'jazz': 9})

# %%
def test_model(dealer, save_name):
    test_result = dict()
    for key in genre_path_dict:
        test_result[key] = 0
        print('test on sample {0}'.format(key))
        for file_name in genre_path_dict.get(key):
            res1, res2, res3, score = cnn_dealer.get_genre(file_name)
            if res1 == label_dict.get(key):
                test_result[key] += score.get(res1)
            elif res2 == label_dict.get(key):
                test_result[key] += score.get(res2)
            elif res3 == label_dict.get(key):
                test_result[key] += score.get(res3)
            print("*"*99)
        test_result[key] /= 300
        print(test_result[key])
        print("+"*99)
    with open(Para.LOG_SAVE_FOLD + save_name, 'w+') as f:
        json.dump(test_result, f)
    return

# %% [markdown]
# # CNN

# %%
test_model(cnn_dealer, 'cnnTest.json')
# Out:
# test on sample pop
# Test on Halsey - Without Me.mp3
# Genre pop: 71.7%
# Genre country: 16.79%
# Genre jazz: 3.28%
# Genre reggae: 2.56%
# Genre classical: 2.17%
# Genre blues: 1.86%
# Genre hiphop: 1.64%
# ***************************************************************************************************
# Test on Camila Cabello - Havana (Official Music VIdeo) ft. Young Thug.mp3
# Genre pop: 37.17%
# Genre blues: 24.99%
# Genre reggae: 20.58%
# Genre country: 10.45%
# Genre rock: 2.78%
# Genre jazz: 2.11%
# Genre hiphop: 1.92%
# ***************************************************************************************************
# Test on Panic! At The Disco - High Hopes (Official Video).mp3
# Genre pop: 58.41%
# Genre country: 22.71%
# Genre reggae: 9.13%
# Genre hiphop: 6.01%
# Genre rock: 3.75%
# ***************************************************************************************************
# 0.557588863799684
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample metal
# Test on Tokyo Ghoul - Unravel [Lyrics].mp3
# Genre pop: 80.89%
# Genre hiphop: 9.81%
# Genre country: 5.31%
# Genre rock: 1.87%
# Genre reggae: 1.12%
# Genre classical: 0.99%
# ***************************************************************************************************
# Test on Black Label Society - Bored To Tears (Sonic Brew)Audio.mp3
# Genre hiphop: 40.85%
# Genre pop: 35.05%
# Genre metal: 14.52%
# Genre rock: 8.23%
# Genre reggae: 1.34%
# ***************************************************************************************************
# Test on Critical Acclaim.mp3
# Genre rock: 39.23%
# Genre hiphop: 27.79%
# Genre pop: 12.69%
# Genre blues: 9.51%
# Genre metal: 8.69%
# Genre classical: 1.42%
# Genre reggae: 0.67%
# ***************************************************************************************************
# 0.04841436058630785
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample disco
# Test on The O'Jays - Love Train.mp3
# Genre country: 62.87%
# Genre rock: 20.4%
# Genre reggae: 10.96%
# Genre pop: 3.38%
# Genre disco: 2.39%
# ***************************************************************************************************
# Test on The Hues CorporationRock The Boat.mp3
# Genre rock: 22.55%
# Genre country: 21.56%
# Genre reggae: 18.66%
# Genre pop: 17.9%
# Genre blues: 15.42%
# Genre hiphop: 2.21%
# Genre disco: 1.71%
# ***************************************************************************************************
# Test on I Will Survive.mp3
# Genre disco: 36.05%
# Genre pop: 32.11%
# Genre blues: 15.57%
# Genre reggae: 9.03%
# Genre country: 3.76%
# Genre hiphop: 2.31%
# Genre rock: 1.16%
# ***************************************************************************************************
# 0.12016508413592565
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample blues
# Test on Freddie KingYou've Got To Love Her With Feeling.mp3
# Genre blues: 69.85%
# Genre reggae: 14.65%
# Genre country: 10.05%
# Genre rock: 3.6%
# Genre jazz: 1.85%
# ***************************************************************************************************
# Test on Big Maceo-Worried Life Blues (1941) HD.mp3
# Genre blues: 76.05%
# Genre country: 11.74%
# Genre jazz: 8.47%
# Genre rock: 2.41%
# Genre pop: 1.33%
# ***************************************************************************************************
# Test on Walking Blues - Robert Johnson - The Complete Recordings.mp3
# Genre blues: 87.67%
# Genre reggae: 10.62%
# Genre pop: 1.71%
# ***************************************************************************************************
# 0.7785665718380297
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample reggae
# Test on Toots & The Maytals - Do The Reggae.mp3
# Genre reggae: 71.8%
# Genre country: 22.97%
# Genre rock: 5.23%
# ***************************************************************************************************
# Test on John HoltPolice In Helicopter.mp3
# Genre reggae: 80.52%
# Genre hiphop: 13.45%
# Genre blues: 6.03%
# ***************************************************************************************************
# Test on Shaggy - Oh Carolina 1993 (Official HQ).mp3
# Genre hiphop: 38.62%
# Genre blues: 38.09%
# Genre pop: 17.13%
# Genre reggae: 6.16%
# ***************************************************************************************************
# 0.5077495356065981
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample classical
# Test on F. ChopinNocturne in c sharp minor for violin and piano YuEun Kim, Violin쇼팽 녹턴바이올리니스트 김유은.mp3
# Genre jazz: 53.37%
# Genre classical: 28.87%
# Genre blues: 10.32%
# Genre country: 7.44%
# ***************************************************************************************************
# Test on Beethoven-Sonata for Piano and Violin no 5, Spring Sonata I.mp3
# Genre country: 35.0%
# Genre jazz: 31.53%
# Genre classical: 16.3%
# Genre blues: 13.64%
# Genre pop: 1.94%
# Genre rock: 1.6%
# ***************************************************************************************************
# Test on Mozart Violin Sonata K.301 Hilary Hahn &amp Natalie Zhu.mp3
# Genre classical: 31.51%
# Genre country: 29.18%
# Genre jazz: 28.02%
# Genre blues: 7.42%
# Genre reggae: 1.83%
# Genre pop: 1.34%
# Genre rock: 0.7%
# ***************************************************************************************************
# 0.25560549037542796
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample rock
# Test on Guns N' Roses - Sweet Child O' Mine (Official Music Video).mp3
# Genre rock: 67.3%
# Genre country: 17.44%
# Genre metal: 6.79%
# Genre disco: 4.68%
# Genre pop: 2.05%
# Genre hiphop: 1.75%
# ***************************************************************************************************
# Test on elvis presley-hound dog.mp3
# Genre pop: 30.37%
# Genre rock: 29.92%
# Genre country: 20.43%
# Genre reggae: 14.51%
# Genre hiphop: 4.77%
# ***************************************************************************************************
# Test on 3 Doors Down - Loser.mp3
# Genre country: 60.62%
# Genre rock: 32.9%
# Genre metal: 2.29%
# Genre pop: 1.81%
# Genre disco: 1.42%
# Genre reggae: 0.95%
# ***************************************************************************************************
# 0.433711206427047
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample hiphop
# Test on Offset - Clout ft. Cardi B.mp3
# Genre pop: 58.2%
# Genre hiphop: 27.11%
# Genre reggae: 9.12%
# Genre blues: 5.57%
# ***************************************************************************************************
# Test on Wu-Tang Clan - C.R.E.A.M. (Official Music Video).mp3
# Genre hiphop: 71.01%
# Genre blues: 18.96%
# Genre reggae: 4.7%
# Genre jazz: 3.89%
# Genre pop: 1.44%
# ***************************************************************************************************
# Test on Dr. Dre ft. Snoop Doggy Dogg - Nuthin' But A G Thang (Dirty) HD.mp3
# Genre hiphop: 80.8%
# Genre reggae: 9.81%
# Genre pop: 5.79%
# Genre blues: 3.6%
# ***************************************************************************************************
# 0.5963790495249115
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample country
# Test on Randy Travis - Forever and Ever, Amen (Official Audio).mp3
# Genre country: 97.85%
# Genre pop: 2.15%
# ***************************************************************************************************
# Test on Lee Ann Womack - I Hope You Dance.mp3
# Genre country: 68.49%
# Genre jazz: 8.48%
# Genre reggae: 6.55%
# Genre classical: 6.32%
# Genre rock: 4.6%
# Genre blues: 2.79%
# Genre pop: 2.75%
# ***************************************************************************************************
# Test on Friends in low places lyrics Garth Brooks.mp3
# Genre country: 97.44%
# Genre rock: 1.46%
# Genre pop: 1.1%
# ***************************************************************************************************
# 0.8792914604765592
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample jazz
# Test on Charles Mingus - Goodbye Pork Pie Hat.mp3
# Genre country: 36.43%
# Genre jazz: 26.6%
# Genre blues: 24.42%
# Genre reggae: 8.62%
# Genre rock: 2.02%
# Genre hiphop: 0.73%
# Genre pop: 0.71%
# Genre classical: 0.47%
# ***************************************************************************************************
# Test on Miles Davis - So What (Audio).mp3
# Genre jazz: 85.56%
# Genre blues: 10.82%
# Genre reggae: 2.16%
# Genre hiphop: 0.83%
# Genre country: 0.63%
# ***************************************************************************************************
# Test on Naima - John Coltrane.mp3
# Genre jazz: 83.87%
# Genre blues: 12.18%
# Genre reggae: 2.83%
# Genre classical: 1.12%
# ***************************************************************************************************
# 0.653434551344719
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
test_model(crnn_dealer, 'crnnTest.json')
# Out:
# test on sample pop
# Test on Halsey - Without Me.mp3
# Genre pop: 71.76%
# Genre country: 15.03%
# Genre blues: 4.37%
# Genre jazz: 3.8%
# Genre reggae: 2.88%
# Genre hiphop: 2.16%
# ***************************************************************************************************
# Test on Camila Cabello - Havana (Official Music VIdeo) ft. Young Thug.mp3
# Genre pop: 42.87%
# Genre blues: 24.22%
# Genre reggae: 19.62%
# Genre country: 6.41%
# Genre rock: 3.62%
# Genre disco: 1.25%
# Genre jazz: 1.25%
# Genre hiphop: 0.76%
# ***************************************************************************************************
# Test on Panic! At The Disco - High Hopes (Official Video).mp3
# Genre pop: 52.18%
# Genre country: 28.93%
# Genre reggae: 8.75%
# Genre hiphop: 6.69%
# Genre rock: 2.31%
# Genre blues: 1.14%
# ***************************************************************************************************
# 0.5560064180587375
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample metal
# Test on Tokyo Ghoul - Unravel [Lyrics].mp3
# Genre pop: 79.42%
# Genre hiphop: 8.26%
# Genre country: 7.08%
# Genre reggae: 4.13%
# Genre rock: 1.11%
# ***************************************************************************************************
# Test on Black Label Society - Bored To Tears (Sonic Brew)Audio.mp3
# Genre hiphop: 40.25%
# Genre pop: 30.6%
# Genre metal: 18.82%
# Genre rock: 4.15%
# Genre blues: 3.58%
# Genre reggae: 2.6%
# ***************************************************************************************************
# Test on Critical Acclaim.mp3
# Genre rock: 35.5%
# Genre hiphop: 31.96%
# Genre pop: 12.02%
# Genre metal: 6.7%
# Genre blues: 6.14%
# Genre reggae: 3.4%
# Genre jazz: 2.31%
# Genre disco: 0.98%
# Genre country: 0.98%
# ***************************************************************************************************
# 0.062733018788231
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample disco
# Test on The O'Jays - Love Train.mp3
# Genre country: 74.26%
# Genre rock: 18.77%
# Genre reggae: 5.13%
# Genre disco: 1.85%
# ***************************************************************************************************
# Test on The Hues CorporationRock The Boat.mp3
# Genre reggae: 29.66%
# Genre country: 19.28%
# Genre blues: 19.19%
# Genre pop: 17.82%
# Genre rock: 11.72%
# Genre hiphop: 2.34%
# ***************************************************************************************************
# Test on I Will Survive.mp3
# Genre pop: 32.68%
# Genre blues: 21.24%
# Genre disco: 19.03%
# Genre country: 12.51%
# Genre reggae: 10.6%
# Genre rock: 2.56%
# Genre hiphop: 1.38%
# ***************************************************************************************************
# 0.06342612160675645
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample blues
# Test on Freddie KingYou've Got To Love Her With Feeling.mp3
# Genre blues: 61.73%
# Genre country: 18.82%
# Genre reggae: 11.91%
# Genre rock: 4.56%
# Genre jazz: 2.98%
# ***************************************************************************************************
# Test on Big Maceo-Worried Life Blues (1941) HD.mp3
# Genre blues: 73.94%
# Genre country: 12.38%
# Genre jazz: 11.05%
# Genre rock: 2.63%
# ***************************************************************************************************
# Test on Walking Blues - Robert Johnson - The Complete Recordings.mp3
# Genre blues: 82.55%
# Genre reggae: 8.22%
# Genre country: 5.17%
# Genre rock: 2.2%
# Genre pop: 1.86%
# ***************************************************************************************************
# 0.7273952443827579
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample reggae
# Test on Toots & The Maytals - Do The Reggae.mp3
# Genre reggae: 87.98%
# Genre country: 6.94%
# Genre rock: 4.02%
# Genre pop: 1.06%
# ***************************************************************************************************
# Test on John HoltPolice In Helicopter.mp3
# Genre reggae: 77.91%
# Genre hiphop: 13.75%
# Genre blues: 8.35%
# ***************************************************************************************************
# Test on Shaggy - Oh Carolina 1993 (Official HQ).mp3
# Genre blues: 50.96%
# Genre hiphop: 34.18%
# Genre pop: 10.28%
# Genre reggae: 4.58%
# ***************************************************************************************************
# 0.5529636802658956
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample classical
# Test on F. ChopinNocturne in c sharp minor for violin and piano YuEun Kim, Violin쇼팽 녹턴바이올리니스트 김유은.mp3
# Genre jazz: 46.45%
# Genre classical: 34.36%
# Genre country: 11.65%
# Genre blues: 5.66%
# Genre pop: 1.88%
# ***************************************************************************************************
# Test on Beethoven-Sonata for Piano and Violin no 5, Spring Sonata I.mp3
# Genre jazz: 36.39%
# Genre country: 33.26%
# Genre classical: 17.06%
# Genre blues: 9.21%
# Genre rock: 2.18%
# Genre pop: 1.89%
# ***************************************************************************************************
# Test on Mozart Violin Sonata K.301 Hilary Hahn &amp Natalie Zhu.mp3
# Genre classical: 30.76%
# Genre country: 27.62%
# Genre jazz: 27.26%
# Genre blues: 8.41%
# Genre reggae: 2.4%
# Genre rock: 1.93%
# Genre pop: 1.63%
# ***************************************************************************************************
# 0.273939924327035
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample rock
# Test on Guns N' Roses - Sweet Child O' Mine (Official Music Video).mp3
# Genre rock: 65.79%
# Genre country: 15.33%
# Genre pop: 8.03%
# Genre metal: 5.48%
# Genre disco: 3.79%
# Genre hiphop: 1.58%
# ***************************************************************************************************
# Test on elvis presley-hound dog.mp3
# Genre rock: 32.9%
# Genre pop: 25.01%
# Genre reggae: 22.18%
# Genre country: 12.36%
# Genre blues: 7.55%
# ***************************************************************************************************
# Test on 3 Doors Down - Loser.mp3
# Genre country: 52.83%
# Genre rock: 44.45%
# Genre pop: 1.52%
# Genre metal: 1.2%
# ***************************************************************************************************
# 0.4771112390042911
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample hiphop
# Test on Offset - Clout ft. Cardi B.mp3
# Genre pop: 56.86%
# Genre hiphop: 29.86%
# Genre reggae: 6.29%
# Genre blues: 4.95%
# Genre jazz: 2.05%
# ***************************************************************************************************
# Test on Wu-Tang Clan - C.R.E.A.M. (Official Music Video).mp3
# Genre hiphop: 75.76%
# Genre blues: 20.57%
# Genre reggae: 2.05%
# Genre pop: 1.62%
# ***************************************************************************************************
# Test on Dr. Dre ft. Snoop Doggy Dogg - Nuthin' But A G Thang (Dirty) HD.mp3
# Genre hiphop: 74.47%
# Genre reggae: 11.04%
# Genre pop: 9.15%
# Genre blues: 5.33%
# ***************************************************************************************************
# 0.6002943055318162
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample country
# Test on Randy Travis - Forever and Ever, Amen (Official Audio).mp3
# Genre country: 100.0%
# ***************************************************************************************************
# Test on Lee Ann Womack - I Hope You Dance.mp3
# Genre country: 60.44%
# Genre rock: 11.79%
# Genre reggae: 11.26%
# Genre jazz: 10.5%
# Genre blues: 3.39%
# Genre classical: 1.59%
# Genre pop: 1.02%
# ***************************************************************************************************
# Test on Friends in low places lyrics Garth Brooks.mp3
# Genre country: 92.25%
# Genre rock: 4.1%
# Genre pop: 3.65%
# ***************************************************************************************************
# 0.8423209629038164
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample jazz
# Test on Charles Mingus - Goodbye Pork Pie Hat.mp3
# Genre country: 38.86%
# Genre jazz: 28.01%
# Genre blues: 20.82%
# Genre reggae: 8.78%
# Genre rock: 3.53%
# ***************************************************************************************************
# Test on Miles Davis - So What (Audio).mp3
# Genre jazz: 85.09%
# Genre blues: 11.12%
# Genre reggae: 2.34%
# Genre hiphop: 1.45%
# ***************************************************************************************************
# Test on Naima - John Coltrane.mp3
# Genre jazz: 89.71%
# Genre blues: 5.56%
# Genre reggae: 2.86%
# Genre classical: 0.99%
# Genre country: 0.88%
# ***************************************************************************************************
# 0.6760254598954631
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
test_model(lcrnn_dealer, 'lcrnnTest.json')
# Out:
# test on sample pop
# Test on Halsey - Without Me.mp3
# Genre pop: 75.96%
# Genre country: 13.12%
# Genre jazz: 6.11%
# Genre blues: 2.51%
# Genre reggae: 2.3%
# ***************************************************************************************************
# Test on Camila Cabello - Havana (Official Music VIdeo) ft. Young Thug.mp3
# Genre pop: 40.19%
# Genre blues: 24.91%
# Genre reggae: 15.73%
# Genre country: 12.03%
# Genre hiphop: 2.54%
# Genre jazz: 2.48%
# Genre rock: 2.12%
# ***************************************************************************************************
# Test on Panic! At The Disco - High Hopes (Official Video).mp3
# Genre pop: 62.19%
# Genre country: 21.89%
# Genre reggae: 9.31%
# Genre hiphop: 4.97%
# Genre rock: 1.64%
# ***************************************************************************************************
# 0.5944579857686754
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample metal
# Test on Tokyo Ghoul - Unravel [Lyrics].mp3
# Genre pop: 77.79%
# Genre hiphop: 9.72%
# Genre country: 8.91%
# Genre blues: 1.3%
# Genre reggae: 1.29%
# Genre metal: 0.98%
# ***************************************************************************************************
# Test on Black Label Society - Bored To Tears (Sonic Brew)Audio.mp3
# Genre pop: 48.93%
# Genre hiphop: 30.93%
# Genre metal: 11.54%
# Genre rock: 6.08%
# Genre reggae: 2.52%
# ***************************************************************************************************
# Test on Critical Acclaim.mp3
# Genre rock: 39.77%
# Genre hiphop: 30.09%
# Genre pop: 14.38%
# Genre blues: 7.0%
# Genre metal: 3.66%
# Genre classical: 2.37%
# Genre country: 2.04%
# Genre reggae: 0.7%
# ***************************************************************************************************
# 0.038465629656065294
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample disco
# Test on The O'Jays - Love Train.mp3
# Genre country: 67.66%
# Genre rock: 15.93%
# Genre reggae: 10.44%
# Genre pop: 4.21%
# Genre disco: 1.76%
# ***************************************************************************************************
# Test on The Hues CorporationRock The Boat.mp3
# Genre reggae: 37.18%
# Genre rock: 24.3%
# Genre pop: 13.27%
# Genre country: 13.17%
# Genre blues: 12.08%
# ***************************************************************************************************
# Test on I Will Survive.mp3
# Genre disco: 26.67%
# Genre pop: 24.1%
# Genre blues: 17.68%
# Genre country: 8.38%
# Genre reggae: 8.24%
# Genre hiphop: 7.64%
# Genre jazz: 3.67%
# Genre rock: 3.62%
# ***************************************************************************************************
# 0.08891613588148965
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample blues
# Test on Freddie KingYou've Got To Love Her With Feeling.mp3
# Genre blues: 63.97%
# Genre country: 23.69%
# Genre reggae: 9.31%
# Genre rock: 3.04%
# ***************************************************************************************************
# Test on Big Maceo-Worried Life Blues (1941) HD.mp3
# Genre blues: 80.94%
# Genre country: 9.01%
# Genre jazz: 7.15%
# Genre rock: 2.9%
# ***************************************************************************************************
# Test on Walking Blues - Robert Johnson - The Complete Recordings.mp3
# Genre blues: 87.02%
# Genre reggae: 9.98%
# Genre jazz: 1.51%
# Genre rock: 1.49%
# ***************************************************************************************************
# 0.7730799011697403
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample reggae
# Test on Toots & The Maytals - Do The Reggae.mp3
# Genre reggae: 78.12%
# Genre country: 20.44%
# Genre blues: 1.44%
# ***************************************************************************************************
# Test on John HoltPolice In Helicopter.mp3
# Genre reggae: 76.18%
# Genre hiphop: 20.74%
# Genre blues: 3.08%
# ***************************************************************************************************
# Test on Shaggy - Oh Carolina 1993 (Official HQ).mp3
# Genre blues: 45.27%
# Genre hiphop: 30.43%
# Genre pop: 18.97%
# Genre reggae: 5.34%
# ***************************************************************************************************
# 0.5143391157535192
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample classical
# Test on F. ChopinNocturne in c sharp minor for violin and piano YuEun Kim, Violin쇼팽 녹턴바이올리니스트 김유은.mp3
# Genre jazz: 52.24%
# Genre classical: 24.79%
# Genre blues: 11.01%
# Genre country: 9.68%
# Genre reggae: 1.15%
# Genre pop: 1.13%
# ***************************************************************************************************
# Test on Beethoven-Sonata for Piano and Violin no 5, Spring Sonata I.mp3
# Genre jazz: 38.05%
# Genre country: 31.15%
# Genre blues: 13.57%
# Genre classical: 12.08%
# Genre pop: 3.49%
# Genre rock: 1.17%
# Genre reggae: 0.48%
# ***************************************************************************************************
# Test on Mozart Violin Sonata K.301 Hilary Hahn &amp Natalie Zhu.mp3
# Genre classical: 33.29%
# Genre country: 29.81%
# Genre jazz: 27.36%
# Genre blues: 5.52%
# Genre rock: 3.08%
# Genre reggae: 0.68%
# Genre pop: 0.26%
# ***************************************************************************************************
# 0.19360640309596439
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample rock
# Test on Guns N' Roses - Sweet Child O' Mine (Official Music Video).mp3
# Genre rock: 68.84%
# Genre country: 12.85%
# Genre metal: 9.15%
# Genre disco: 4.08%
# Genre pop: 3.39%
# Genre hiphop: 1.69%
# ***************************************************************************************************
# Test on elvis presley-hound dog.mp3
# Genre pop: 30.23%
# Genre rock: 28.5%
# Genre country: 19.72%
# Genre blues: 14.81%
# Genre reggae: 6.75%
# ***************************************************************************************************
# Test on 3 Doors Down - Loser.mp3
# Genre country: 61.52%
# Genre rock: 36.73%
# Genre metal: 1.75%
# ***************************************************************************************************
# 0.44691458125273614
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample hiphop
# Test on Offset - Clout ft. Cardi B.mp3
# Genre pop: 49.93%
# Genre hiphop: 32.5%
# Genre reggae: 15.34%
# Genre blues: 2.22%
# ***************************************************************************************************
# Test on Wu-Tang Clan - C.R.E.A.M. (Official Music Video).mp3
# Genre hiphop: 66.85%
# Genre blues: 20.35%
# Genre reggae: 7.96%
# Genre pop: 3.34%
# Genre jazz: 1.5%
# ***************************************************************************************************
# Test on Dr. Dre ft. Snoop Doggy Dogg - Nuthin' But A G Thang (Dirty) HD.mp3
# Genre hiphop: 75.87%
# Genre reggae: 10.04%
# Genre blues: 9.45%
# Genre pop: 4.64%
# ***************************************************************************************************
# 0.5840568299738607
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample country
# Test on Randy Travis - Forever and Ever, Amen (Official Audio).mp3
# Genre country: 98.61%
# Genre rock: 1.39%
# ***************************************************************************************************
# Test on Lee Ann Womack - I Hope You Dance.mp3
# Genre country: 62.93%
# Genre pop: 8.6%
# Genre jazz: 8.27%
# Genre rock: 8.15%
# Genre classical: 4.84%
# Genre reggae: 4.39%
# Genre blues: 2.81%
# ***************************************************************************************************
# Test on Friends in low places lyrics Garth Brooks.mp3
# Genre country: 95.43%
# Genre pop: 2.47%
# Genre rock: 2.1%
# ***************************************************************************************************
# 0.856546419662075
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample jazz
# Test on Charles Mingus - Goodbye Pork Pie Hat.mp3
# Genre country: 36.92%
# Genre jazz: 29.49%
# Genre blues: 17.42%
# Genre reggae: 11.73%
# Genre rock: 4.01%
# Genre hiphop: 0.43%
# ***************************************************************************************************
# Test on Miles Davis - So What (Audio).mp3
# Genre jazz: 83.69%
# Genre blues: 10.6%
# Genre reggae: 4.35%
# Genre hiphop: 1.35%
# ***************************************************************************************************
# Test on Naima - John Coltrane.mp3
# Genre jazz: 83.37%
# Genre blues: 15.07%
# Genre reggae: 1.56%
# ***************************************************************************************************
# 0.655160981293152
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Make Graphs

# %%
import matplotlib.pyplot as plt

# %%
with open(Para.LOG_SAVE_FOLD + 'cnnTest.json', 'r') as f:
    cnn = json.load(f)
with open(Para.LOG_SAVE_FOLD + 'crnnTest.json', 'r') as f:
    crnn = json.load(f)
with open(Para.LOG_SAVE_FOLD + 'lcrnnTest.json', 'r') as f:
    lcrnn = json.load(f)

# %%
plt.figure(figsize=(10,10))
plt.bar(range(len(cnn)), cnn.values(), 
        align='center', 
        color= (0,0,0,0),
        edgecolor = 'r',
        label='cnn model')

plt.bar(range(len(crnn)), crnn.values(), 
        align='center', 
        color=(0,0,0,0),
        edgecolor = 'b',
        label='crnnI model')

plt.bar(range(len(lcrnn)), lcrnn.values(), 
        align='center', 
        color=(0,0,0,0),
        edgecolor = 'g',
        label='crnnII model')

plt.xticks(range(len(cnn)), cnn.keys())
plt.show()
