# %% [markdown]
# # Music Predictor
# Using this file to predict the genre of a given music file

# %%
from music_dealer import MusicDealer
from models import CnnModel, CrnnLongModel, CrnnModel 
import json
from Paras import Para
import os

# %%
WEIGHT_PATH = "../model/"
cnn_dealer = MusicDealer(WEIGHT_PATH + "CnnModel.pt", CnnModel())
crnn_dealer = MusicDealer(WEIGHT_PATH + "CrnnModel.pt", CrnnModel())
lcrnn_dealer = MusicDealer(WEIGHT_PATH + "CrnnLongModel.pt", CrnnLongModel(), 256)

# %% [markdown]
# # Sample Music  Paths

# %%
data_path = '../sample_music'
genre_path_dict = dict()
label_dict = Para.r_dictionary

for (dirpath, dirnames, filenames) in os.walk(data_path):
    if dirnames:
        for idx, genre in enumerate(dirnames):
            genre_path_dict[genre] = list()
        continue
    else:
        genre = dirpath.split('/')[-1]
        for au_file in filenames:
            if 'mp3' in au_file:
                current_path = dirpath + '/' + au_file
                genre_path_dict[genre].append(current_path)

total_file = sum([len(genre_path_dict[genre]) for genre in genre_path_dict])
total_file, label_dict
# Out:
# (30,
#  {'pop': 0,
#   'metal': 1,
#   'disco': 2,
#   'blues': 3,
#   'reggae': 4,
#   'classical': 5,
#   'rock': 6,
#   'hiphop': 7,
#   'country': 8,
#   'jazz': 9})

# %%
def test_model(dealer, save_name):
    test_result = dict()
    for key in genre_path_dict:
        test_result[key] = 0
        print('test on sample {0}'.format(key))
        for file_name in genre_path_dict.get(key):
            res1, res2, res3, score = dealer.get_genre(file_name)
            if res1 == label_dict.get(key):
                test_result[key] += score.get(res1)
            elif res2 == label_dict.get(key):
                test_result[key] += score.get(res2)
            elif res3 == label_dict.get(key):
                test_result[key] += score.get(res3)
            print("*"*99)
        test_result[key] /= 300
        print(test_result[key])
        print("+"*99)
    with open(Para.LOG_SAVE_FOLD + save_name, 'w+') as f:
        json.dump(test_result, f)
    return

# %% [markdown]
# # CNN

# %%
test_model(cnn_dealer, 'cnnTest.json')
# Out:
# test on sample reggae
# Test on Shaggy - Oh Carolina 1993 (Official HQ).mp3
# Genre pop: 47.15%
# Genre hiphop: 41.56%
# Genre blues: 6.13%
# Genre reggae: 5.16%
# ***************************************************************************************************
# Test on Toots & The Maytals - Do The Reggae.mp3
# Genre reggae: 98.67%
# Genre blues: 1.33%
# ***************************************************************************************************
# Test on John HoltPolice In Helicopter.mp3
# Genre reggae: 91.71%
# Genre hiphop: 6.19%
# Genre blues: 2.1%
# ***************************************************************************************************
# 0.6346058600757705
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample disco
# Test on The O'Jays - Love Train.mp3
# Genre disco: 78.67%
# Genre rock: 19.59%
# Genre country: 1.74%
# ***************************************************************************************************
# Test on I Will Survive.mp3
# Genre disco: 93.43%
# Genre pop: 5.28%
# Genre reggae: 1.29%
# ***************************************************************************************************
# Test on The Hues CorporationRock The Boat.mp3
# Genre blues: 42.24%
# Genre rock: 23.07%
# Genre pop: 18.66%
# Genre reggae: 11.48%
# Genre country: 4.55%
# ***************************************************************************************************
# 0.573668634564919
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample metal
# Test on Critical Acclaim.mp3
# Genre metal: 79.58%
# Genre hiphop: 10.89%
# Genre rock: 4.42%
# Genre classical: 3.3%
# Genre blues: 0.95%
# Genre pop: 0.84%
# ***************************************************************************************************
# Test on Tokyo Ghoul - Unravel [Lyrics].mp3
# Genre pop: 84.58%
# Genre metal: 7.59%
# Genre hiphop: 5.64%
# Genre classical: 2.19%
# ***************************************************************************************************
# Test on Black Label Society - Bored To Tears (Sonic Brew)Audio.mp3
# Genre metal: 79.44%
# Genre hiphop: 14.42%
# Genre pop: 6.14%
# ***************************************************************************************************
# 0.5553914256999678
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample blues
# Test on Big Maceo-Worried Life Blues (1941) HD.mp3
# Genre blues: 88.48%
# Genre jazz: 11.52%
# ***************************************************************************************************
# Test on Freddie KingYou've Got To Love Her With Feeling.mp3
# Genre blues: 84.22%
# Genre jazz: 15.78%
# ***************************************************************************************************
# Test on Walking Blues - Robert Johnson - The Complete Recordings.mp3
# Genre blues: 79.27%
# Genre hiphop: 20.73%
# ***************************************************************************************************
# 0.8399308096580941
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample hiphop
# Test on Wu-Tang Clan - C.R.E.A.M. (Official Music Video).mp3
# Genre hiphop:

# ***************************************************************************************************
# Test on Black Label Society - Bored To Tears (Sonic Brew)Audio.mp3
# Genre metal: 83.78%
# Genre hiphop: 12.27%
# Genre pop: 3.95%
# ***************************************************************************************************
# 0.724898471199443
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample blues
# Test on Big Maceo-Worried Life Blues (1941) HD.mp3
# Genre blues: 56.71%
# Genre jazz: 40.54%
# Genre country: 2.75%
# ***************************************************************************************************
# Test on Freddie KingYou've Got To Love Her With Feeling.mp3
# Genre blues: 49.93%
# Genre jazz: 40.58%
# Genre country: 4.65%
# Genre hiphop: 2.01%
# Genre reggae: 1.58%
# Genre rock: 1.24%
# ***************************************************************************************************
# Test on Walking Blues - Robert Johnson - The Complete Recordings.mp3
# Genre blues: 63.18%
# Genre hiphop: 23.09%
# Genre reggae: 13.73%
# ***************************************************************************************************
# 0.5660637418205261
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample hiphop
# Test on Wu-Tang Clan - C.R.E.A.M. (Official Music Video).mp3
# Genre hiphop: 85.27%
# Genre blues: 7.09%
# Genre reggae: 5.57%
# Genre jazz: 1.29%
# Genre disco: 0.78%
# ***************************************************************************************************
# Test on Dr. Dre ft. Snoop Doggy Dogg - Nuthin' But A G Thang (Dirty) HD.mp3
# Genre hiphop: 95.06%
# Genre blues: 2.55%
# Genre reggae: 1.69%
# Genre pop: 0.69%
# ***************************************************************************************************
# Test on Offset - Clout ft. Cardi B.mp3
# Genre hiphop: 63.78%
# Genre pop: 33.73%
# Genre blues: 2.49%
# ***************************************************************************************************
# 0.8137015504845071
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample rock
# Test on elvis presley-hound dog.mp3
# Genre rock: 43.66%
# Genre metal: 18.93%
# Genre blues: 11.97%
# Genre hiphop: 9.56%
# Genre disco: 8.15%
# Genre country: 7.73%
# ***************************************************************************************************
# Test on Guns N' Roses - Sweet Child O' Mine (Official Music Video).mp3
# Genre metal: 90.95%
# Genre rock: 7.32%
# Genre disco: 1.74%
# ***************************************************************************************************
# Test on 3 Doors Down - Loser.mp3
# Genre rock: 55.67%
# Genre metal: 23.34%
# Genre country: 20.99%
# ***************************************************************************************************
# 0.3554774853963001
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample pop
# Test on Panic! At The Disco - High Hopes (Official Video).mp3
# Genre pop: 70.0%
# Genre country: 24.52%
# Genre hiphop: 2.84%
# Genre reggae: 1.5%
# Genre rock: 1.13%
# ***************************************************************************************************
# Test on Camila Cabello - Havana (Official Music VIdeo) ft. Young Thug.mp3
# Genre pop: 47.62%
# Genre hiphop: 18.96%
# Genre blues: 17.23%
# Genre classical: 6.34%
# Genre reggae: 5.59%
# Genre rock: 4.25%
# ***************************************************************************************************
# Test on Halsey - Without Me.mp3
# Genre pop: 92.6%
# Genre reggae: 2.64%
# Genre country: 2.16%
# Genre classical: 1.58%
# Genre hiphop: 1.02%
# ***************************************************************************************************
# 0.700753397111294
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample classical
# Test on F. ChopinNocturne in c sharp minor for violin and piano YuEun Kim, Violin쇼팽 녹턴바이올리니스트 김유은.mp3
# Genre classical: 100.0%
# ***************************************************************************************************
# Test on Beethoven-Sonata for Piano and Violin no 5, Spring Sonata I.mp3
# Genre classical: 99.0%
# Genre jazz: 1.0%
# ***************************************************************************************************
# Test on Mozart Violin Sonata K.301 Hilary Hahn &amp Natalie Zhu.mp3
# Genre classical: 100.0%
# ***************************************************************************************************
# 0.9966799220850711
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample jazz
# Test on Miles Davis - So What (Audio).mp3
# Genre jazz: 100.0%
# ***************************************************************************************************
# Test on Naima - John Coltrane.mp3
# Genre jazz: 90.1%
# Genre classical: 9.9%
# ***************************************************************************************************
# Test on Charles Mingus - Goodbye Pork Pie Hat.mp3
# Genre jazz: 71.26%
# Genre classical: 13.68%
# Genre blues: 7.52%
# Genre country: 4.32%
# Genre rock: 3.22%
# ***************************************************************************************************
# 0.871184916013677
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample country
# Test on Friends in low places lyrics Garth Brooks.mp3
# Genre country: 80.72%
# Genre rock: 18.37%
# Genre metal: 0.9%
# ***************************************************************************************************
# Test on Lee Ann Womack - I Hope You Dance.mp3
# Genre rock: 29.51%
# Genre country: 27.52%
# Genre classical: 24.51%
# Genre jazz: 12.34%
# Genre reggae: 4.88%
# Genre disco: 1.24%
# ***************************************************************************************************
# Test on Randy Travis - Forever and Ever, Amen (Official Audio).mp3
# Genre country: 100.0%
# ***************************************************************************************************
# 0.6941583015456422
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %%
test_model(lcrnn_dealer, 'lcrnnTest.json')
# Out:
# test on sample reggae
# Test on Shaggy - Oh Carolina 1993 (Official HQ).mp3
# Genre pop: 73.75%
# Genre hiphop: 23.18%
# Genre reggae: 3.07%
# ***************************************************************************************************
# Test on Toots & The Maytals - Do The Reggae.mp3
# Genre reggae: 96.48%
# Genre blues: 3.52%
# ***************************************************************************************************
# Test on John HoltPolice In Helicopter.mp3
# Genre reggae: 100.0%
# ***************************************************************************************************
# 0.6651951826822047
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample disco
# Test on The O'Jays - Love Train.mp3
# Genre disco: 97.87%
# Genre blues: 2.13%
# ***************************************************************************************************
# Test on I Will Survive.mp3
# Genre disco: 83.81%
# Genre pop: 16.19%
# ***************************************************************************************************
# Test on The Hues CorporationRock The Boat.mp3
# Genre disco: 51.46%
# Genre blues: 26.94%
# Genre rock: 8.98%
# Genre country: 5.82%
# Genre hiphop: 3.4%
# Genre reggae: 3.4%
# ***************************************************************************************************
# 0.7771497770729218
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample metal
# Test on Critical Acclaim.mp3
# Genre metal: 91.15%
# Genre classical: 3.18%
# Genre hiphop: 3.07%
# Genre disco: 2.6%
# ***************************************************************************************************
# Test on Tokyo Ghoul - Unravel [Lyrics].mp3
# Genre metal: 51.34%
# Genre pop: 37.05%
# Genre hiphop: 7.84%
# Genre classical: 3.77%
# ***************************************************************************************************
# Test on Black Label Society - Bored To Tears (Sonic Brew)Audio.mp3
# Genre metal: 87.16%
# Genre hiphop: 10.68%
# Genre pop: 2.16%
# ***************************************************************************************************
# 0.765506120290974
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample blues
# Test on Big Maceo-Worried Life Blues (1941) HD.mp3
# Genre blues: 89.37%
# Genre jazz: 10.63%
# ***************************************************************************************************
# Test on Freddie KingYou've Got To Love Her With Feeling.mp3
# Genre blues: 77.62%
# Genre jazz: 16.92%
# Genre reggae: 5.46%
# ***************************************************************************************************
# Test on Walking Blues - Robert Johnson - The Complete Recordings.mp3
# Genre blues: 100.0%
# ***************************************************************************************************
# 0.8899940460898366
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample hiphop
# Test on Wu-Tang Clan - C.R.E.A.M. (Official Music Video).mp3
# Genre hiphop: 95.79%
# Genre blues: 4.21%
# ***************************************************************************************************
# Test on Dr. Dre ft. Snoop Doggy Dogg - Nuthin' But A G Thang (Dirty) HD.mp3
# Genre hiphop: 98.26%
# Genre blues: 1.74%
# ***************************************************************************************************
# Test on Offset - Clout ft. Cardi B.mp3
# Genre hiphop: 73.56%
# Genre pop: 26.44%
# ***************************************************************************************************
# 0.8920196953748116
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample rock
# Test on elvis presley-hound dog.mp3
# Genre country: 29.52%
# Genre pop: 26.97%
# Genre disco: 16.55%
# Genre rock: 15.6%
# Genre metal: 6.64%
# Genre reggae: 4.73%
# ***************************************************************************************************
# Test on Guns N' Roses - Sweet Child O' Mine (Official Music Video).mp3
# Genre metal: 96.17%
# Genre rock: 3.83%
# ***************************************************************************************************
# Test on 3 Doors Down - Loser.mp3
# Genre rock: 55.35%
# Genre metal: 35.75%
# Genre country: 8.91%
# ***************************************************************************************************
# 0.19726989470125236
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample pop
# Test on Panic! At The Disco - High Hopes (Official Video).mp3
# Genre pop: 90.56%
# Genre country: 3.55%
# Genre hiphop: 2.95%
# Genre disco: 2.94%
# ***************************************************************************************************
# Test on Camila Cabello - Havana (Official Music VIdeo) ft. Young Thug.mp3
# Genre pop: 47.81%
# Genre blues: 30.52%
# Genre hiphop: 8.41%
# Genre country: 6.23%
# Genre jazz: 3.12%
# Genre rock: 2.38%
# Genre reggae: 1.53%
# ***************************************************************************************************
# Test on Halsey - Without Me.mp3
# Genre pop: 84.2%
# Genre reggae: 11.28%
# Genre country: 2.38%
# Genre hiphop: 2.14%
# ***************************************************************************************************
# 0.7418832039979653
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample classical
# Test on F. ChopinNocturne in c sharp minor for violin and piano YuEun Kim, Violin쇼팽 녹턴바이올리니스트 김유은.mp3
# Genre classical: 100.0%
# ***************************************************************************************************
# Test on Beethoven-Sonata for Piano and Violin no 5, Spring Sonata I.mp3
# Genre classical: 91.2%
# Genre jazz: 4.0%
# Genre country: 3.57%
# Genre pop: 1.23%
# ***************************************************************************************************
# Test on Mozart Violin Sonata K.301 Hilary Hahn &amp Natalie Zhu.mp3
# Genre classical: 99.17%
# Genre jazz: 0.83%
# ***************************************************************************************************
# 0.9678890333062886
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample jazz
# Test on Miles Davis - So What (Audio).mp3
# Genre jazz: 100.0%
# ***************************************************************************************************
# Test on Naima - John Coltrane.mp3
# Genre jazz: 95.89%
# Genre classical: 4.11%
# ***************************************************************************************************
# Test on Charles Mingus - Goodbye Pork Pie Hat.mp3
# Genre jazz: 64.88%
# Genre country: 11.7%
# Genre classical: 11.26%
# Genre blues: 8.82%
# Genre rock: 2.59%
# Genre reggae: 0.76%
# ***************************************************************************************************
# 0.8692396606580983
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# test on sample country
# Test on Friends in low places lyrics Garth Brooks.mp3
# Genre country: 84.56%
# Genre rock: 11.2%
# Genre disco: 2.15%
# Genre pop: 2.09%
# ***************************************************************************************************
# Test on Lee Ann Womack - I Hope You Dance.mp3
# Genre country: 54.17%
# Genre rock: 19.05%
# Genre classical: 18.57%
# Genre pop: 5.22%
# Genre reggae: 2.99%
# ***************************************************************************************************
# Test on Randy Travis - Forever and Ever, Amen (Official Audio).mp3
# Genre country: 100.0%
# ***************************************************************************************************
# 0.7957753797089727
# +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++

# %% [markdown]
# # Make Graphs

# %%
import matplotlib.pyplot as plt

# %%
with open(Para.LOG_SAVE_FOLD + 'cnnTest.json', 'r') as f:
    cnn = json.load(f)
with open(Para.LOG_SAVE_FOLD + 'crnnTest.json', 'r') as f:
    crnn = json.load(f)
with open(Para.LOG_SAVE_FOLD + 'lcrnnTest.json', 'r') as f:
    lcrnn = json.load(f)

# %%
plt.figure(figsize=(10,10))
plt.bar(range(len(cnn)), cnn.values(), 
        align='center', 
        color= (0,0,0,0),
        edgecolor = 'r',
        label='cnn model')

plt.bar(range(len(crnn)), crnn.values(), 
        align='center', 
        color=(0,0,0,0),
        edgecolor = 'b',
        label='crnnI model')

plt.bar(range(len(lcrnn)), lcrnn.values(), 
        align='center', 
        color=(0,0,0,0),
        edgecolor = 'g',
        label='crnnII model')

plt.xticks(range(len(cnn)), cnn.keys())
plt.legend(loc="upper left")
plt.show()
