# %%
import time
import numpy as np

from basic_model import M_model
import torch
from torch import optim
from util import bce_loss, accuracy_function
from Paras import Para

from data_loader import train_loader, validation_loader, test_loader

Para.dataset_len = len(train_loader)
Para.log_step = len(train_loader) // 4

optimizer = torch.optim.RMSprop(M_model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)


def train(model, epoch, versatile=True):
    start_time = time.time()
    model = model.train()
    train_loss = 0.
    accuracy = 0.
    batch_num = len(train_loader)
    _index = 0

    for _index, data in enumerate(train_loader):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        optimizer.zero_grad()
        predicted = model(spec_input)

        loss_value = bce_loss(predicted, target)
        accuracy_value = accuracy_function(predicted, target)

        loss_value.backward()
        optimizer.step()

        train_loss += loss_value.data.item()
        accuracy += accuracy_value

        if versatile:
            if (_index + 1) % Para.log_step == 0:
                elapsed = time.time() - start_time
                print('Epoch{:3d} | {:3d}/{:3d} batches | {:5.2f}ms/ batch | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
                      .format(epoch, _index + 1, batch_num,
                              elapsed * 1000 / (_index + 1),
                              train_loss / (_index + 1),
                              accuracy * 100 / (_index + 1)))

    train_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('-' * 99)
    print('End of training epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  train_loss, accuracy * 100))

    return train_loss, accuracy


def validate_test(model, epoch, test=False):
    start_time = time.time()
    model = model.eval()
    v_loss = 0.
    accuracy = 0.
    data_loader_use = validation_loader if not test else test_loader
    _index = 0
    for _index, data in enumerate(data_loader_use):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        with torch.no_grad():

            predicted = model(spec_input)

            loss_value = bce_loss(predicted, target)
            accuracy_value = accuracy_function(predicted, target)

            v_loss += loss_value.data.item()
            accuracy += accuracy_value

    v_loss /= (_index + 1)
    accuracy /= (_index + 1)

    if not test:
        print('End of validation epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format(epoch, (time.time() - start_time),
                v_loss, accuracy * 100))
    else:
        print('End of Test | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format((time.time() - start_time),
                v_loss, accuracy * 100))
    print('-' * 99)

    return v_loss, accuracy

# %% [markdown]
# # Train the model here

# %%
Para.cuda
# Out:
# True

# %%
t_loss, t_accu, v_loss, v_accu = [], [], [], []
decay_cnt = 0

for epoch in range(1, Para.epoch_num + 1):
    if Para.cuda:
        M_model.cuda()

    train_loss, train_accuracy = train(M_model, epoch)
    validation_loss, validation_accuracy = validate_test(M_model, epoch, test=False)

    t_loss.append(train_loss)
    t_accu.append(train_accuracy)

    v_loss.append(validation_loss)
    v_accu.append(validation_accuracy)

    # use accuracy to find the best model
    if np.max(t_accu) == t_accu[-1]:
        print('***Found Best Training Model***')
    if np.max(v_accu) == v_accu[-1]:
        with open(Para.MODEL_SAVE_PATH_1, 'wb') as f:
            torch.save(M_model.cpu().state_dict(), f)
            print('***Best Validation Model Found and Saved***')

    print('-' * 99)

    # Use BCE loss value for learning rate scheduling
    decay_cnt += 1

    if np.min(t_loss) not in t_loss[-3:] and decay_cnt > 2:
        scheduler.step()
        decay_cnt = 0
        print('***Learning rate decreased***')
        print('-' * 99)
# Out:
# Epoch  1 |  87/350 batches | 18.49ms/ batch | BCE: 0.2977 | Accuracy: 23.56% |
# Epoch  1 | 174/350 batches | 18.02ms/ batch | BCE: 0.2794 | Accuracy: 29.60% |
# Epoch  1 | 261/350 batches | 17.86ms/ batch | BCE: 0.2686 | Accuracy: 32.66% |
# Epoch  1 | 348/350 batches | 17.76ms/ batch | BCE: 0.2621 | Accuracy: 34.99% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time:  6.24s | BCE: 0.2619 | Accuracy: 35.04% |
# End of validation epoch   1 | time:  0.37s | BCE: 0.2114 | Accuracy: 51.23% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 |  87/350 batches | 18.11ms/ batch | BCE: 0.2281 | Accuracy: 44.83% |
# Epoch  2 | 174/350 batches | 17.83ms/ batch | BCE: 0.2253 | Accuracy: 45.62% |
# Epoch  2 | 261/350 batches | 17.74ms/ batch | BCE: 0.2198 | Accuracy: 47.65% |
# Epoch  2 | 348/350 batches | 17.73ms/ batch | BCE: 0.2154 | Accuracy: 49.14% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time:  6.23s | BCE: 0.2155 | Accuracy: 49.14% |
# End of validation epoch   2 | time:  0.37s | BCE: 0.1863 | Accuracy: 59.09% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 |  87/350 batches | 18.15ms/ batch | BCE: 0.1921 | Accuracy: 56.39% |
# Epoch  3 | 174/350 batches | 17.89ms/ batch | BCE: 0.1879 | Accuracy: 58.23% |
# Epoch  3 | 261/350 batches | 17.82ms/ batch | BCE: 0.1887 | Accuracy: 58.60% |
# Epoch  3 | 348/350 batches | 17.78ms/ batch | BCE: 0.1844 | Accuracy: 59.95% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time:  6.25s | BCE: 0.1844 | Accuracy: 59.96% |
# End of validation epoch   3 | time:  0.36s | BCE: 0.1489 | Accuracy: 68.99% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 |  87/350 batches | 18.27ms/ batch | BCE: 0.1580 | Accuracy: 65.52% |
# Epoch  4 | 174/350 batches | 17.98ms/ batch | BCE: 0.1564 | Accuracy: 66.74% |
# Epoch  4 | 261/350 batches | 17.91ms/ batch | BCE: 0.1554 | Accuracy: 67.15% |
# Epoch  4 | 348/350 batches | 17.83ms/ batch | BCE: 0.1551 | Accuracy: 67.19% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time:  6.26s | BCE: 0.1553 | Accuracy: 67.09% |
# End of validation epoch   4 | time:  0.39s | BCE: 0.1345 | Accuracy: 70.98% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 |  87/350 batches | 18.14ms/ batch | BCE: 0.1447 | Accuracy: 71.77% |
# Epoch  5 | 174/350 batches | 17.84ms/ batch | BCE: 0.1417 | Accuracy: 71.34% |
# Epoch  5 | 261/350 batches | 17.76ms/ batch | BCE: 0.1379 | Accuracy: 72.34% |
# Epoch  5 | 348/350 batches | 17.75ms/ batch | BCE: 0.1350 | Accuracy: 72.79% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time:  6.24s | BCE: 0.1349 | Accuracy: 72.82% |
# End of validation epoch   5 | time:  0.36s | BCE: 0.1322 | Accuracy: 71.92% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 |  87/350 batches | 18.13ms/ batch | BCE: 0.1247 | Accuracy: 75.65% |
# Epoch  6 | 174/350 batches | 17.88ms/ batch | BCE: 0.1209 | Accuracy: 76.04% |
# Epoch  6 | 261/350 batches | 17.82ms/ batch | BCE: 0.1208 | Accuracy: 75.81% |
# Epoch  6 | 348/350 batches | 17.77ms/ batch | BCE: 0.1182 | Accuracy: 76.13% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time:  6.24s | BCE: 0.1181 | Accuracy: 76.18% |
# End of validation epoch   6 | time:  0.34s | BCE: 0.1638 | Accuracy: 67.14% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 |  87/350 batches | 18.19ms/ batch | BCE: 0.1082 | Accuracy: 78.02% |
# Epoch  7 | 174/350 batches | 17.99ms/ batch | BCE: 0.1050 | Accuracy: 78.63% |
# Epoch  7 | 261/350 batches | 17.88ms/ batch | BCE: 0.1043 | Accuracy: 78.86% |
# Epoch  7 | 348/350 batches | 17.85ms/ batch | BCE: 0.1048 | Accuracy: 78.84% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time:  6.27s | BCE: 0.1049 | Accuracy: 78.80% |
# End of validation epoch   7 | time:  0.36s | BCE: 0.1102 | Accuracy: 77.08% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 |  87/350 batches | 18.11ms/ batch | BCE: 0.0972 | Accuracy: 81.47% |
# Epoch  8 | 174/350 batches | 17.90ms/ batch | BCE: 0.0965 | Accuracy: 81.29% |
# Epoch  8 | 261/350 batches | 17.79ms/ batch | BCE: 0.0949 | Accuracy: 81.80% |
# Epoch  8 | 348/350 batches | 17.75ms/ batch | BCE: 0.0942 | Accuracy: 81.79% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time:  6.23s | BCE: 0.0940 | Accuracy: 81.84% |
# End of validation epoch   8 | time:  0.42s | BCE: 0.1187 | Accuracy: 75.71% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 |  87/350 batches | 18.04ms/ batch | BCE: 0.0806 | Accuracy: 84.41% |
# Epoch  9 | 174/350 batches | 17.88ms/ batch | BCE: 0.0810 | Accuracy: 83.62% |
# Epoch  9 | 261/350 batches | 17.78ms/ batch | BCE: 0.0805 | Accuracy: 83.72% |
# Epoch  9 | 348/350 batches | 17.74ms/ batch | BCE: 0.0809 | Accuracy: 84.05% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time:  6.23s | BCE: 0.0809 | Accuracy: 84.05% |
# End of validation epoch   9 | time:  0.36s | BCE: 0.1268 | Accuracy: 74.10% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 |  87/350 batches | 18.19ms/ batch | BCE: 0.0688 | Accuracy: 87.00% |
# Epoch 10 | 174/350 batches | 17.86ms/ batch | BCE: 0.0703 | Accuracy: 86.75% |
# Epoch 10 | 261/350 batches | 17.74ms/ batch | BCE: 0.0692 | Accuracy: 86.95% |
# Epoch 10 | 348/350 batches | 17.69ms/ batch | BCE: 0.0698 | Accuracy: 86.73% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time:  6.21s | BCE: 0.0698 | Accuracy: 86.71% |
# End of validation epoch  10 | time:  0.36s | BCE: 0.0919 | Accuracy: 81.77% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 |  87/350 batches | 18.13ms/ batch | BCE: 0.0580 | Accuracy: 89.73% |
# Epoch 11 | 174/350 batches | 17.84ms/ batch | BCE: 0.0601 | Accuracy: 89.15% |
# Epoch 11 | 261/350 batches | 17.79ms/ batch | BCE: 0.0619 | Accuracy: 88.53% |
# Epoch 11 | 348/350 batches | 17.75ms/ batch | BCE: 0.0625 | Accuracy: 88.34% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time:  6.24s | BCE: 0.0624 | Accuracy: 88.38% |
# End of validation epoch  11 | time:  0.36s | BCE: 0.1069 | Accuracy: 77.46% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 |  87/350 batches | 18.05ms/ batch | BCE: 0.0454 | Accuracy: 91.95% |
# Epoch 12 | 174/350 batches | 17.77ms/ batch | BCE: 0.0487 | Accuracy: 91.27% |
# Epoch 12 | 261/350 batches | 17.71ms/ batch | BCE: 0.0522 | Accuracy: 90.16% |
# Epoch 12 | 348/350 batches | 17.66ms/ batch | BCE: 0.0534 | Accuracy: 89.67% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time:  6.21s | BCE: 0.0535 | Accuracy: 89.68% |
# End of validation epoch  12 | time:  0.35s | BCE: 0.0949 | Accuracy: 81.96% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 |  87/350 batches | 18.07ms/ batch | BCE: 0.0419 | Accuracy: 92.24% |
# Epoch 13 | 174/350 batches | 17.79ms/ batch | BCE: 0.0431 | Accuracy: 92.21% |
# Epoch 13 | 261/350 batches | 17.70ms/ batch | BCE: 0.0456 | Accuracy: 91.93% |
# Epoch 13 | 348/350 batches | 17.67ms/ batch | BCE: 0.0464 | Accuracy: 91.59% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time:  6.21s | BCE: 0.0463 | Accuracy: 91.61% |
# End of validation epoch  13 | time:  0.41s | BCE: 0.0750 | Accuracy: 84.28% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 |  87/350 batches | 18.16ms/ batch | BCE: 0.0406 | Accuracy: 92.89% |
# Epoch 14 | 174/350 batches | 17.89ms/ batch | BCE: 0.0411 | Accuracy: 92.56% |
# Epoch 14 | 261/350 batches | 17.78ms/ batch | BCE: 0.0430 | Accuracy: 91.86% |
# Epoch 14 | 348/350 batches | 17.73ms/ batch | BCE: 0.0413 | Accuracy: 92.19% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time:  6.23s | BCE: 0.0412 | Accuracy: 92.23% |
# End of validation epoch  14 | time:  0.36s | BCE: 0.0798 | Accuracy: 84.75% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 |  87/350 batches | 18.24ms/ batch | BCE: 0.0380 | Accuracy: 92.89% |
# Epoch 15 | 174/350 batches | 17.97ms/ batch | BCE: 0.0351 | Accuracy: 93.61% |
# Epoch 15 | 261/350 batches | 17.84ms/ batch | BCE: 0.0345 | Accuracy: 93.85% |
# Epoch 15 | 348/350 batches | 17.80ms/ batch | BCE: 0.0372 | Accuracy: 93.46% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time:  6.26s | BCE: 0.0372 | Accuracy: 93.48% |
# End of validation epoch  15 | time:  0.39s | BCE: 0.0873 | Accuracy: 83.48% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 |  87/350 batches | 18.40ms/ batch | BCE: 0.0241 | Accuracy: 95.98% |
# Epoch 16 | 174/350 batches | 18.02ms/ batch | BCE: 0.0303 | Accuracy: 94.79% |
# Epoch 16 | 261/350 batches | 17.85ms/ batch | BCE: 0.0331 | Accuracy: 94.25% |
# Epoch 16 | 348/350 batches | 17.85ms/ batch | BCE: 0.0320 | Accuracy: 94.36% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time:  6.27s | BCE: 0.0320 | Accuracy: 94.34% |
# End of validation epoch  16 | time:  0.37s | BCE: 0.0745 | Accuracy: 86.51% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 |  87/350 batches | 18.23ms/ batch | BCE: 0.0253 | Accuracy: 95.19% |
# Epoch 17 | 174/350 batches | 17.92ms/ batch | BCE: 0.0252 | Accuracy: 95.26% |
# Epoch 17 | 261/350 batches | 17.79ms/ batch | BCE: 0.0267 | Accuracy: 94.97% |
# Epoch 17 | 348/350 batches | 17.73ms/ batch | BCE: 0.0276 | Accuracy: 94.86% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time:  6.22s | BCE: 0.0276 | Accuracy: 94.88% |
# End of validation epoch  17 | time:  0.38s | BCE: 0.1627 | Accuracy: 74.43% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 |  87/350 batches | 18.04ms/ batch | BCE: 0.0232 | Accuracy: 95.83% |
# Epoch 18 | 174/350 batches | 17.80ms/ batch | BCE: 0.0254 | Accuracy: 95.58% |
# Epoch 18 | 261/350 batches | 17.72ms/ batch | BCE: 0.0237 | Accuracy: 95.98% |
# Epoch 18 | 348/350 batches | 17.68ms/ batch | BCE: 0.0260 | Accuracy: 95.33% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time:  6.21s | BCE: 0.0261 | Accuracy: 95.34% |
# End of validation epoch  18 | time:  0.35s | BCE: 0.0884 | Accuracy: 85.04% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 |  87/350 batches | 18.27ms/ batch | BCE: 0.0209 | Accuracy: 96.19% |
# Epoch 19 | 174/350 batches | 17.96ms/ batch | BCE: 0.0203 | Accuracy: 96.52% |
# Epoch 19 | 261/350 batches | 17.89ms/ batch | BCE: 0.0226 | Accuracy: 96.05% |
# Epoch 19 | 348/350 batches | 17.83ms/ batch | BCE: 0.0208 | Accuracy: 96.28% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time:  6.26s | BCE: 0.0208 | Accuracy: 96.29% |
# End of validation epoch  19 | time:  0.34s | BCE: 0.1054 | Accuracy: 84.04% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 |  87/350 batches | 18.14ms/ batch | BCE: 0.0215 | Accuracy: 96.34% |
# Epoch 20 | 174/350 batches | 17.87ms/ batch | BCE: 0.0225 | Accuracy: 95.87% |
# Epoch 20 | 261/350 batches | 17.81ms/ batch | BCE: 0.0233 | Accuracy: 95.52% |
# Epoch 20 | 348/350 batches | 17.78ms/ batch | BCE: 0.0225 | Accuracy: 95.87% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time:  6.24s | BCE: 0.0225 | Accuracy: 95.88% |
# End of validation epoch  20 | time:  0.35s | BCE: 0.1762 | Accuracy: 75.33% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
# visualization
plt.figure()
plt.plot(t_accu, c='b', label='Training set accuracy')
plt.plot(v_accu, c='r', label='Validation set accuracy')
plt.title('Accuracy vs Epochs / pure CNN Model')
plt.legend()
plt.show()

# %% [markdown]
# ## Test Model on Test Set

# %%
M_model.load_state_dict(torch.load(Para.MODEL_SAVE_PATH_1))
validate_test(M_model, 0, test=True)
# Out:
# End of Test | time:  0.35s | BCE: 0.1015 | Accuracy: 84.52% |
# ---------------------------------------------------------------------------------------------------
# (0.10151177274846387, 0.8451704545454546)
