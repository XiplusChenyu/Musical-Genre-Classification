# %%
import time
import numpy as np

from gru_model import G_model
import torch
from torch import optim
from util import bce_loss, accuracy_function
from Paras import Para

from data_loader import fin_train_loader, fin_validation_loader, fin_test_loader

Para.dataset_len = len(fin_train_loader)
Para.log_step = len(fin_train_loader) // 4


optimizer = torch.optim.RMSprop(G_model.parameters(), lr=1e-4)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)

def train(model, epoch, versatile=True):
    start_time = time.time()
    model = model.train()
    train_loss = 0.
    accuracy = 0.
    batch_num = len(fin_train_loader)
    _index = 0

    for _index, data in enumerate(fin_train_loader):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        optimizer.zero_grad()
        predicted = model(spec_input)

        loss_value = bce_loss(predicted, target)
        accuracy_value = accuracy_function(predicted, target)

        loss_value.backward()
        optimizer.step()

        train_loss += loss_value.data.item()
        accuracy += accuracy_value

        if versatile:
            if (_index + 1) % Para.log_step == 0:
                elapsed = time.time() - start_time
                print('Epoch{:3d} | {:3d}/{:3d} batches | {:5.2f}ms/ batch | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
                      .format(epoch, _index + 1, batch_num,
                              elapsed * 1000 / (_index + 1),
                              train_loss / (_index + 1),
                              accuracy * 100 / (_index + 1)))

    train_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('-' * 99)
    print('End of training epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  train_loss, accuracy * 100))

    return train_loss, accuracy


def validate_test(model, epoch, test=False):
    start_time = time.time()
    model = model.eval()
    v_loss = 0.
    accuracy = 0.
    data_loader_use = fin_validation_loader if not test else fin_test_loader
    _index = 0
    for _index, data in enumerate(data_loader_use):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        with torch.no_grad():

            predicted = model(spec_input)

            loss_value = bce_loss(predicted, target)
            accuracy_value = accuracy_function(predicted, target)

            v_loss += loss_value.data.item()
            accuracy += accuracy_value

    v_loss /= (_index + 1)
    accuracy /= (_index + 1)

    if not test:
        print('End of validation epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format(epoch, (time.time() - start_time),
                v_loss, accuracy * 100))
    else:
        print('End of Test | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format((time.time() - start_time),
                v_loss, accuracy * 100))
    print('-' * 99)

    return v_loss, accuracy

# %% [markdown]
# # Train the model here

# %%
t_loss, t_accu, v_loss, v_accu = [], [], [], []
decay_cnt = 0

for epoch in range(1, Para.epoch_num + 1):
    if Para.cuda:
        G_model.cuda()

    train_loss, train_accuracy = train(G_model, epoch)
    validation_loss, validation_accuracy = validate_test(G_model, epoch, test=False)

    t_loss.append(train_loss)
    t_accu.append(train_accuracy)

    v_loss.append(validation_loss)
    v_accu.append(validation_accuracy)

    # use accuracy to find the best model
    if np.max(t_accu) == t_accu[-1]:
        print('***Found Best Training Model***')
    if np.max(v_accu) == v_accu[-1]:
        with open(Para.MODEL_SAVE_PATH_2A, 'wb') as f:
            torch.save(G_model.cpu().state_dict(), f)
            print('***Best Validation Model Found and Saved***')

    print('-' * 99)

    # Use BCE loss value for learning rate scheduling
    decay_cnt += 1

    if np.min(t_loss) not in t_loss[-3:] and decay_cnt > 2:
        scheduler.step()
        decay_cnt = 0
        print('***Learning rate decreased***')
        print('-' * 99)
# Out:
# Epoch  1 | 154/619 batches | 17.50ms/ batch | BCE: 0.2770 | Accuracy: 33.60% |
# Epoch  1 | 308/619 batches | 17.23ms/ batch | BCE: 0.2544 | Accuracy: 40.65% |
# Epoch  1 | 462/619 batches | 17.15ms/ batch | BCE: 0.2407 | Accuracy: 44.01% |
# Epoch  1 | 616/619 batches | 17.12ms/ batch | BCE: 0.2288 | Accuracy: 47.12% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 10.61s | BCE: 0.2288 | Accuracy: 47.15% |
# End of validation epoch   1 | time:  0.57s | BCE: 0.1623 | Accuracy: 67.37% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 154/619 batches | 17.40ms/ batch | BCE: 0.1818 | Accuracy: 61.85% |
# Epoch  2 | 308/619 batches | 17.24ms/ batch | BCE: 0.1741 | Accuracy: 63.78% |
# Epoch  2 | 462/619 batches | 17.19ms/ batch | BCE: 0.1719 | Accuracy: 63.91% |
# Epoch  2 | 616/619 batches | 17.12ms/ batch | BCE: 0.1687 | Accuracy: 64.34% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 10.62s | BCE: 0.1686 | Accuracy: 64.38% |
# End of validation epoch   2 | time:  0.63s | BCE: 0.1270 | Accuracy: 75.30% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 154/619 batches | 17.53ms/ batch | BCE: 0.1469 | Accuracy: 70.86% |
# Epoch  3 | 308/619 batches | 17.31ms/ batch | BCE: 0.1425 | Accuracy: 70.94% |
# Epoch  3 | 462/619 batches | 17.22ms/ batch | BCE: 0.1404 | Accuracy: 71.25% |
# Epoch  3 | 616/619 batches | 17.18ms/ batch | BCE: 0.1387 | Accuracy: 71.59% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time: 10.65s | BCE: 0.1387 | Accuracy: 71.60% |
# End of validation epoch   3 | time:  0.58s | BCE: 0.1166 | Accuracy: 77.16% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 | 154/619 batches | 17.35ms/ batch | BCE: 0.1226 | Accuracy: 74.19% |
# Epoch  4 | 308/619 batches | 17.21ms/ batch | BCE: 0.1193 | Accuracy: 74.96% |
# Epoch  4 | 462/619 batches | 17.18ms/ batch | BCE: 0.1185 | Accuracy: 75.23% |
# Epoch  4 | 616/619 batches | 17.12ms/ batch | BCE: 0.1173 | Accuracy: 75.67% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time: 10.62s | BCE: 0.1173 | Accuracy: 75.71% |
# End of validation epoch   4 | time:  0.57s | BCE: 0.1080 | Accuracy: 78.33% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 | 154/619 batches | 17.29ms/ batch | BCE: 0.1046 | Accuracy: 78.53% |
# Epoch  5 | 308/619 batches | 17.18ms/ batch | BCE: 0.1027 | Accuracy: 79.00% |
# Epoch  5 | 462/619 batches | 17.10ms/ batch | BCE: 0.1014 | Accuracy: 79.52% |
# Epoch  5 | 616/619 batches | 17.13ms/ batch | BCE: 0.1019 | Accuracy: 79.63% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time: 10.62s | BCE: 0.1018 | Accuracy: 79.65% |
# End of validation epoch   5 | time:  0.58s | BCE: 0.1042 | Accuracy: 79.63% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 | 154/619 batches | 17.52ms/ batch | BCE: 0.0865 | Accuracy: 83.16% |
# Epoch  6 | 308/619 batches | 17.32ms/ batch | BCE: 0.0884 | Accuracy: 82.81% |
# Epoch  6 | 462/619 batches | 17.23ms/ batch | BCE: 0.0902 | Accuracy: 82.37% |
# Epoch  6 | 616/619 batches | 17.18ms/ batch | BCE: 0.0905 | Accuracy: 82.31% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time: 10.65s | BCE: 0.0905 | Accuracy: 82.29% |
# End of validation epoch   6 | time:  0.64s | BCE: 0.0929 | Accuracy: 82.13% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 | 154/619 batches | 17.43ms/ batch | BCE: 0.0773 | Accuracy: 85.43% |
# Epoch  7 | 308/619 batches | 17.19ms/ batch | BCE: 0.0774 | Accuracy: 85.09% |
# Epoch  7 | 462/619 batches | 17.13ms/ batch | BCE: 0.0763 | Accuracy: 85.35% |
# Epoch  7 | 616/619 batches | 17.10ms/ batch | BCE: 0.0771 | Accuracy: 85.24% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time: 10.61s | BCE: 0.0775 | Accuracy: 85.19% |
# End of validation epoch   7 | time:  0.54s | BCE: 0.1005 | Accuracy: 80.69% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 | 154/619 batches | 17.56ms/ batch | BCE: 0.0704 | Accuracy: 86.93% |
# Epoch  8 | 308/619 batches | 17.40ms/ batch | BCE: 0.0685 | Accuracy: 87.07% |
# Epoch  8 | 462/619 batches | 17.32ms/ batch | BCE: 0.0690 | Accuracy: 86.84% |
# Epoch  8 | 616/619 batches | 17.27ms/ batch | BCE: 0.0687 | Accuracy: 86.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time: 10.71s | BCE: 0.0688 | Accuracy: 86.80% |
# End of validation epoch   8 | time:  0.56s | BCE: 0.1087 | Accuracy: 79.47% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 | 154/619 batches | 17.40ms/ batch | BCE: 0.0606 | Accuracy: 88.35% |
# Epoch  9 | 308/619 batches | 17.20ms/ batch | BCE: 0.0598 | Accuracy: 88.80% |
# Epoch  9 | 462/619 batches | 17.12ms/ batch | BCE: 0.0627 | Accuracy: 88.43% |
# Epoch  9 | 616/619 batches | 17.11ms/ batch | BCE: 0.0628 | Accuracy: 88.30% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time: 10.61s | BCE: 0.0627 | Accuracy: 88.33% |
# End of validation epoch   9 | time:  0.55s | BCE: 0.0874 | Accuracy: 84.21% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 | 154/619 batches | 17.49ms/ batch | BCE: 0.0503 | Accuracy: 89.98% |
# Epoch 10 | 308/619 batches | 17.32ms/ batch | BCE: 0.0509 | Accuracy: 89.96% |
# Epoch 10 | 462/619 batches | 17.21ms/ batch | BCE: 0.0529 | Accuracy: 89.79% |
# Epoch 10 | 616/619 batches | 17.15ms/ batch | BCE: 0.0536 | Accuracy: 89.66% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time: 10.63s | BCE: 0.0536 | Accuracy: 89.65% |
# End of validation epoch  10 | time:  0.59s | BCE: 0.0825 | Accuracy: 85.90% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 | 154/619 batches | 17.32ms/ batch | BCE: 0.0475 | Accuracy: 90.62% |
# Epoch 11 | 308/619 batches | 17.23ms/ batch | BCE: 0.0492 | Accuracy: 90.62% |
# Epoch 11 | 462/619 batches | 17.14ms/ batch | BCE: 0.0507 | Accuracy: 90.41% |
# Epoch 11 | 616/619 batches | 17.15ms/ batch | BCE: 0.0502 | Accuracy: 90.47% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time: 10.63s | BCE: 0.0503 | Accuracy: 90.48% |
# End of validation epoch  11 | time:  0.57s | BCE: 0.0953 | Accuracy: 83.80% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 | 154/619 batches | 17.46ms/ batch | BCE: 0.0443 | Accuracy: 92.17% |
# Epoch 12 | 308/619 batches | 17.29ms/ batch | BCE: 0.0438 | Accuracy: 91.96% |
# Epoch 12 | 462/619 batches | 17.20ms/ batch | BCE: 0.0433 | Accuracy: 92.05% |
# Epoch 12 | 616/619 batches | 17.21ms/ batch | BCE: 0.0447 | Accuracy: 91.78% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time: 10.67s | BCE: 0.0446 | Accuracy: 91.80% |
# End of validation epoch  12 | time:  0.57s | BCE: 0.1143 | Accuracy: 81.88% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 | 154/619 batches | 17.54ms/ batch | BCE: 0.0334 | Accuracy: 94.24% |
# Epoch 13 | 308/619 batches | 17.38ms/ batch | BCE: 0.0352 | Accuracy: 93.71% |
# Epoch 13 | 462/619 batches | 17.34ms/ batch | BCE: 0.0369 | Accuracy: 93.30% |
# Epoch 13 | 616/619 batches | 17.28ms/ batch | BCE: 0.0390 | Accuracy: 92.86% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time: 10.72s | BCE: 0.0391 | Accuracy: 92.85% |
# End of validation epoch  13 | time:  0.60s | BCE: 0.1340 | Accuracy: 80.19% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 | 154/619 batches | 17.43ms/ batch | BCE: 0.0337 | Accuracy: 93.95% |
# Epoch 14 | 308/619 batches | 17.25ms/ batch | BCE: 0.0371 | Accuracy: 93.43% |
# Epoch 14 | 462/619 batches | 17.28ms/ batch | BCE: 0.0375 | Accuracy: 93.20% |
# Epoch 14 | 616/619 batches | 17.29ms/ batch | BCE: 0.0378 | Accuracy: 93.00% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time: 10.72s | BCE: 0.0380 | Accuracy: 93.00% |
# End of validation epoch  14 | time:  0.59s | BCE: 0.1149 | Accuracy: 82.50% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 | 154/619 batches | 17.53ms/ batch | BCE: 0.0355 | Accuracy: 93.43% |
# Epoch 15 | 308/619 batches | 17.28ms/ batch | BCE: 0.0356 | Accuracy: 93.38% |
# Epoch 15 | 462/619 batches | 17.25ms/ batch | BCE: 0.0359 | Accuracy: 93.43% |
# Epoch 15 | 616/619 batches | 17.20ms/ batch | BCE: 0.0358 | Accuracy: 93.42% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time: 10.66s | BCE: 0.0360 | Accuracy: 93.38% |
# End of validation epoch  15 | time:  0.65s | BCE: 0.1960 | Accuracy: 72.15% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 | 154/619 batches | 17.52ms/ batch | BCE: 0.0295 | Accuracy: 94.85% |
# Epoch 16 | 308/619 batches | 17.34ms/ batch | BCE: 0.0316 | Accuracy: 94.12% |
# Epoch 16 | 462/619 batches | 17.26ms/ batch | BCE: 0.0308 | Accuracy: 94.29% |
# Epoch 16 | 616/619 batches | 17.19ms/ batch | BCE: 0.0317 | Accuracy: 94.02% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time: 10.66s | BCE: 0.0320 | Accuracy: 94.01% |
# End of validation epoch  16 | time:  0.61s | BCE: 0.1049 | Accuracy: 84.84% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 | 154/619 batches | 17.60ms/ batch | BCE: 0.0297 | Accuracy: 94.56% |
# Epoch 17 | 308/619 batches | 17.36ms/ batch | BCE: 0.0298 | Accuracy: 94.70% |
# Epoch 17 | 462/619 batches | 17.20ms/ batch | BCE: 0.0283 | Accuracy: 95.02% |
# Epoch 17 | 616/619 batches | 17.18ms/ batch | BCE: 0.0284 | Accuracy: 95.03% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time: 10.65s | BCE: 0.0283 | Accuracy: 95.04% |
# End of validation epoch  17 | time:  0.55s | BCE: 0.0925 | Accuracy: 86.54% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 | 154/619 batches | 17.50ms/ batch | BCE: 0.0283 | Accuracy: 95.33% |
# Epoch 18 | 308/619 batches | 17.36ms/ batch | BCE: 0.0286 | Accuracy: 94.97% |
# Epoch 18 | 462/619 batches | 17.31ms/ batch | BCE: 0.0284 | Accuracy: 94.78% |
# Epoch 18 | 616/619 batches | 17.29ms/ batch | BCE: 0.0281 | Accuracy: 94.98% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time: 10.72s | BCE: 0.0282 | Accuracy: 94.96% |
# End of validation epoch  18 | time:  0.57s | BCE: 0.1166 | Accuracy: 83.70% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# Epoch 19 | 154/619 batches | 17.35ms/ batch | BCE: 0.0210 | Accuracy: 96.14% |
# Epoch 19 | 308/619 batches | 17.23ms/ batch | BCE: 0.0236 | Accuracy: 96.02% |
# Epoch 19 | 462/619 batches | 17.17ms/ batch | BCE: 0.0248 | Accuracy: 95.71% |
# Epoch 19 | 616/619 batches | 17.10ms/ batch | BCE: 0.0250 | Accuracy: 95.59% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time: 10.60s | BCE: 0.0249 | Accuracy: 95.61% |
# End of validation epoch  19 | time:  0.55s | BCE: 0.1013 | Accuracy: 86.86% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 | 154/619 batches | 17.48ms/ batch | BCE: 0.0209 | Accuracy: 96.67% |
# Epoch 20 | 308/619 batches | 17.28ms/ batch | BCE: 0.0247 | Accuracy: 95.82% |
# Epoch 20 | 462/619 batches | 17.24ms/ batch | BCE: 0.0252 | Accuracy: 95.52% |
# Epoch 20 | 616/619 batches | 17.18ms/ batch | BCE: 0.0251 | Accuracy: 95.50% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time: 10.65s | BCE: 0.0250 | Accuracy: 95.51% |
# End of validation epoch  20 | time:  0.56s | BCE: 0.1100 | Accuracy: 85.56% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(t_accu, c='b', label='Training set accuracy')
plt.plot(v_accu, c='r', label='Validation set accuracy')
plt.title('Accuracy vs Epochs / GRU-CNN Model')
plt.legend()
plt.show()

# %%
G_model.load_state_dict(torch.load(Para.MODEL_SAVE_PATH_2A))
validate_test(G_model, 0, test=True)
# Out:
# End of Test | time:  0.58s | BCE: 0.0985 | Accuracy: 86.38% |
# ---------------------------------------------------------------------------------------------------
# (0.09847592089014749, 0.8637820512820513)
