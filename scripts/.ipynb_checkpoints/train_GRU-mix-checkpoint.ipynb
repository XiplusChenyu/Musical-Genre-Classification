# %%
import time
import numpy as np

from gru_model import G_model
import torch
from torch import optim
from util import bce_loss, accuracy_function
from Paras import Para

from data_loader import fin_train_loader, fin_validation_loader, fin_test_loader

Para.dataset_len = len(fin_train_loader)
Para.log_step = len(fin_train_loader) // 4


optimizer = torch.optim.RMSprop(G_model.parameters(), lr=1e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.5)

def train(model, epoch, versatile=True):
    start_time = time.time()
    model = model.train()
    train_loss = 0.
    accuracy = 0.
    batch_num = len(fin_train_loader)
    _index = 0

    for _index, data in enumerate(fin_train_loader):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        optimizer.zero_grad()
        predicted = model(spec_input)

        loss_value = bce_loss(predicted, target)
        accuracy_value = accuracy_function(predicted, target)

        loss_value.backward()
        optimizer.step()

        train_loss += loss_value.data.item()
        accuracy += accuracy_value

        if versatile:
            if (_index + 1) % Para.log_step == 0:
                elapsed = time.time() - start_time
                print('Epoch{:3d} | {:3d}/{:3d} batches | {:5.2f}ms/ batch | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
                      .format(epoch, _index + 1, batch_num,
                              elapsed * 1000 / (_index + 1),
                              train_loss / (_index + 1),
                              accuracy * 100 / (_index + 1)))

    train_loss /= (_index + 1)
    accuracy /= (_index + 1)

    print('-' * 99)
    print('End of training epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
          .format(epoch, (time.time() - start_time),
                  train_loss, accuracy * 100))

    return train_loss, accuracy


def validate_test(model, epoch, test=False):
    start_time = time.time()
    model = model.eval()
    v_loss = 0.
    accuracy = 0.
    data_loader_use = fin_validation_loader if not test else fin_test_loader
    _index = 0
    for _index, data in enumerate(data_loader_use):
        spec_input, target = data['mel'], data['tag']

        if Para.cuda:
            spec_input = spec_input.cuda()
            target = target.cuda()

        with torch.no_grad():

            predicted = model(spec_input)

            loss_value = bce_loss(predicted, target)
            accuracy_value = accuracy_function(predicted, target)

            v_loss += loss_value.data.item()
            accuracy += accuracy_value

    v_loss /= (_index + 1)
    accuracy /= (_index + 1)

    if not test:
        print('End of validation epoch {:3d} | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format(epoch, (time.time() - start_time),
                v_loss, accuracy * 100))
    else:
        print('End of Test | time: {:5.2f}s | BCE: {:5.4f} | Accuracy: {:5.2f}% |'
              .format((time.time() - start_time),
                v_loss, accuracy * 100))
    print('-' * 99)

    return v_loss, accuracy

# %% [markdown]
# # Train the model here

# %%
Para.epoch_num = 50

# %%
t_loss, t_accu, v_loss, v_accu = [], [], [], []
decay_cnt = 0

for epoch in range(1, Para.epoch_num + 1):
    if Para.cuda:
        G_model.cuda()

    train_loss, train_accuracy = train(G_model, epoch)
    validation_loss, validation_accuracy = validate_test(G_model, epoch, test=False)

    t_loss.append(train_loss)
    t_accu.append(train_accuracy)

    v_loss.append(validation_loss)
    v_accu.append(validation_accuracy)

    # use accuracy to find the best model
    if np.max(t_accu) == t_accu[-1]:
        print('***Found Best Training Model***')
    if np.max(v_accu) == v_accu[-1]:
        with open(Para.MODEL_SAVE_PATH_2A, 'wb') as f:
            torch.save(G_model.cpu().state_dict(), f)
            print('***Best Validation Model Found and Saved***')

    print('-' * 99)

    # Use BCE loss value for learning rate scheduling
    decay_cnt += 1

    if np.min(t_loss) not in t_loss[-3:] and decay_cnt > 2:
        scheduler.step()
        decay_cnt = 0
        print('***Learning rate decreased***')
        print('-' * 99)
# Out:
# Epoch  1 | 154/619 batches | 17.63ms/ batch | BCE: 0.3207 | Accuracy: 16.36% |
# Epoch  1 | 308/619 batches | 17.35ms/ batch | BCE: 0.3168 | Accuracy: 19.95% |
# Epoch  1 | 462/619 batches | 17.30ms/ batch | BCE: 0.3131 | Accuracy: 22.10% |
# Epoch  1 | 616/619 batches | 17.29ms/ batch | BCE: 0.3097 | Accuracy: 23.43% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 10.72s | BCE: 0.3095 | Accuracy: 23.48% |
# End of validation epoch   1 | time:  0.56s | BCE: 0.2850 | Accuracy: 34.49% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 154/619 batches | 17.40ms/ batch | BCE: 0.2920 | Accuracy: 30.40% |
# Epoch  2 | 308/619 batches | 17.21ms/ batch | BCE: 0.2905 | Accuracy: 30.44% |
# Epoch  2 | 462/619 batches | 17.16ms/ batch | BCE: 0.2870 | Accuracy: 31.80% |
# Epoch  2 | 616/619 batches | 17.11ms/ batch | BCE: 0.2847 | Accuracy: 32.61% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 10.61s | BCE: 0.2846 | Accuracy: 32.59% |
# End of validation epoch   2 | time:  0.57s | BCE: 0.2568 | Accuracy: 39.95% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 154/619 batches | 17.44ms/ batch | BCE: 0.2734 | Accuracy: 35.11% |
# Epoch  3 | 308/619 batches | 17.30ms/ batch | BCE: 0.2687 | Accuracy: 36.10% |
# Epoch  3 | 462/619 batches | 17.25ms/ batch | BCE: 0.2632 | Accuracy: 37.39% |
# Epoch  3 | 616/619 batches | 17.22ms/ batch | BCE: 0.2614 | Accuracy: 37.50% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time: 10.68s | BCE: 0.2614 | Accuracy: 37.52% |
# End of validation epoch   3 | time:  0.55s | BCE: 0.2318 | Accuracy: 42.85% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 | 154/619 batches | 17.35ms/ batch | BCE: 0.2499 | Accuracy: 39.94% |
# Epoch  4 | 308/619 batches | 17.14ms/ batch | BCE: 0.2470 | Accuracy: 41.60% |
# Epoch  4 | 462/619 batches | 17.12ms/ batch | BCE: 0.2444 | Accuracy: 42.55% |
# Epoch  4 | 616/619 batches | 17.07ms/ batch | BCE: 0.2437 | Accuracy: 42.90% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time: 10.59s | BCE: 0.2438 | Accuracy: 42.90% |
# End of validation epoch   4 | time:  0.59s | BCE: 0.2156 | Accuracy: 51.51% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 | 154/619 batches | 17.36ms/ batch | BCE: 0.2321 | Accuracy: 45.13% |
# Epoch  5 | 308/619 batches | 17.23ms/ batch | BCE: 0.2289 | Accuracy: 46.83% |
# Epoch  5 | 462/619 batches | 17.18ms/ batch | BCE: 0.2294 | Accuracy: 46.93% |
# Epoch  5 | 616/619 batches | 17.17ms/ batch | BCE: 0.2286 | Accuracy: 47.39% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time: 10.65s | BCE: 0.2285 | Accuracy: 47.39% |
# End of validation epoch   5 | time:  0.55s | BCE: 0.2028 | Accuracy: 55.66% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 | 154/619 batches | 17.32ms/ batch | BCE: 0.2201 | Accuracy: 50.57% |
# Epoch  6 | 308/619 batches | 17.15ms/ batch | BCE: 0.2199 | Accuracy: 50.67% |
# Epoch  6 | 462/619 batches | 17.08ms/ batch | BCE: 0.2184 | Accuracy: 51.11% |
# Epoch  6 | 616/619 batches | 17.07ms/ batch | BCE: 0.2178 | Accuracy: 51.21% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time: 10.59s | BCE: 0.2176 | Accuracy: 51.24% |
# End of validation epoch   6 | time:  0.55s | BCE: 0.1911 | Accuracy: 57.74% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 | 154/619 batches | 17.39ms/ batch | BCE: 0.2093 | Accuracy: 53.90% |
# Epoch  7 | 308/619 batches | 17.26ms/ batch | BCE: 0.2089 | Accuracy: 53.55% |
# Epoch  7 | 462/619 batches | 17.18ms/ batch | BCE: 0.2099 | Accuracy: 53.31% |
# Epoch  7 | 616/619 batches | 17.15ms/ batch | BCE: 0.2081 | Accuracy: 53.84% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time: 10.63s | BCE: 0.2081 | Accuracy: 53.85% |
# End of validation epoch   7 | time:  0.60s | BCE: 0.1795 | Accuracy: 60.63% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 | 154/619 batches | 17.34ms/ batch | BCE: 0.2018 | Accuracy: 55.56% |
# Epoch  8 | 308/619 batches | 17.15ms/ batch | BCE: 0.2009 | Accuracy: 55.78% |
# Epoch  8 | 462/619 batches | 17.08ms/ batch | BCE: 0.1995 | Accuracy: 56.13% |
# Epoch  8 | 616/619 batches | 17.07ms/ batch | BCE: 0.1984 | Accuracy: 56.41% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time: 10.59s | BCE: 0.1985 | Accuracy: 56.37% |
# End of validation epoch   8 | time:  0.54s | BCE: 0.1706 | Accuracy: 64.47% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 | 154/619 batches | 17.29ms/ batch | BCE: 0.1939 | Accuracy: 57.06% |
# Epoch  9 | 308/619 batches | 17.16ms/ batch | BCE: 0.1939 | Accuracy: 57.55% |
# Epoch  9 | 462/619 batches | 17.11ms/ batch | BCE: 0.1917 | Accuracy: 58.32% |
# Epoch  9 | 616/619 batches | 17.12ms/ batch | BCE: 0.1903 | Accuracy: 58.46% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time: 10.62s | BCE: 0.1904 | Accuracy: 58.43% |
# End of validation epoch   9 | time:  0.61s | BCE: 0.1615 | Accuracy: 65.77% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 | 154/619 batches | 17.32ms/ batch | BCE: 0.1837 | Accuracy: 61.97% |
# Epoch 10 | 308/619 batches | 17.18ms/ batch | BCE: 0.1823 | Accuracy: 61.32% |
# Epoch 10 | 462/619 batches | 17.15ms/ batch | BCE: 0.1816 | Accuracy: 61.40% |
# Epoch 10 | 616/619 batches | 17.13ms/ batch | BCE: 0.1813 | Accuracy: 61.48% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time: 10.62s | BCE: 0.1815 | Accuracy: 61.38% |
# End of validation epoch  10 | time:  0.53s | BCE: 0.1539 | Accuracy: 68.33% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 | 154/619 batches | 17.36ms/ batch | BCE: 0.1731 | Accuracy: 62.58% |
# Epoch 11 | 308/619 batches | 17.20ms/ batch | BCE: 0.1750 | Accuracy: 62.52% |
# Epoch 11 | 462/619 batches | 17.17ms/ batch | BCE: 0.1744 | Accuracy: 62.96% |
# Epoch 11 | 616/619 batches | 17.15ms/ batch | BCE: 0.1730 | Accuracy: 63.32% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time: 10.64s | BCE: 0.1734 | Accuracy: 63.24% |
# End of validation epoch  11 | time:  0.55s | BCE: 0.1482 | Accuracy: 69.38% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 | 154/619 batches | 17.46ms/ batch | BCE: 0.1634 | Accuracy: 65.22% |
# Epoch 12 | 308/619 batches | 17.27ms/ batch | BCE: 0.1673 | Accuracy: 63.86% |
# Epoch 12 | 462/619 batches | 17.17ms/ batch | BCE: 0.1664 | Accuracy: 64.46% |
# Epoch 12 | 616/619 batches | 17.13ms/ batch | BCE: 0.1656 | Accuracy: 64.69% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time: 10.62s | BCE: 0.1656 | Accuracy: 64.64% |
# End of validation epoch  12 | time:  0.54s | BCE: 0.1417 | Accuracy: 70.98% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 | 154/619 batches | 17.40ms/ batch | BCE: 0.1613 | Accuracy: 66.48% |
# Epoch 13 | 308/619 batches | 17.27ms/ batch | BCE: 0.1615 | Accuracy: 66.17% |
# Epoch 13 | 462/619 batches | 17.20ms/ batch | BCE: 0.1592 | Accuracy: 66.63% |
# Epoch 13 | 616/619 batches | 17.17ms/ batch | BCE: 0.1584 | Accuracy: 66.76% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time: 10.65s | BCE: 0.1583 | Accuracy: 66.76% |
# End of validation epoch  13 | time:  0.61s | BCE: 0.1354 | Accuracy: 72.20% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 | 154/619 batches | 17.48ms/ batch | BCE: 0.1513 | Accuracy: 68.02% |
# Epoch 14 | 308/619 batches | 17.30ms/ batch | BCE: 0.1503 | Accuracy: 68.36% |
# Epoch 14 | 462/619 batches | 17.25ms/ batch | BCE: 0.1508 | Accuracy: 68.24% |
# Epoch 14 | 616/619 batches | 17.22ms/ batch | BCE: 0.1509 | Accuracy: 68.17% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time: 10.68s | BCE: 0.1508 | Accuracy: 68.21% |
# End of validation epoch  14 | time:  0.61s | BCE: 0.1305 | Accuracy: 72.68% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 | 154/619 batches | 17.39ms/ batch | BCE: 0.1444 | Accuracy: 69.48% |
# Epoch 15 | 308/619 batches | 17.21ms/ batch | BCE: 0.1440 | Accuracy: 69.74% |
# Epoch 15 | 462/619 batches | 17.15ms/ batch | BCE: 0.1437 | Accuracy: 69.53% |
# Epoch 15 | 616/619 batches | 17.11ms/ batch | BCE: 0.1445 | Accuracy: 69.52% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time: 10.61s | BCE: 0.1445 | Accuracy: 69.53% |
# End of validation epoch  15 | time:  0.55s | BCE: 0.1263 | Accuracy: 74.84% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 | 154/619 batches | 17.22ms/ batch | BCE: 0.1395 | Accuracy: 71.71% |
# Epoch 16 | 308/619 batches | 17.14ms/ batch | BCE: 0.1422 | Accuracy: 70.68% |
# Epoch 16 | 462/619 batches | 17.12ms/ batch | BCE: 0.1404 | Accuracy: 71.14% |
# Epoch 16 | 616/619 batches | 17.12ms/ batch | BCE: 0.1411 | Accuracy: 70.94% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time: 10.61s | BCE: 0.1413 | Accuracy: 70.88% |
# End of validation epoch  16 | time:  0.55s | BCE: 0.1212 | Accuracy: 75.88% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 | 154/619 batches | 17.31ms/ batch | BCE: 0.1341 | Accuracy: 73.70% |
# Epoch 17 | 308/619 batches | 17.20ms/ batch | BCE: 0.1361 | Accuracy: 72.24% |
# Epoch 17 | 462/619 batches | 17.17ms/ batch | BCE: 0.1358 | Accuracy: 72.15% |
# Epoch 17 | 616/619 batches | 17.15ms/ batch | BCE: 0.1350 | Accuracy: 72.32% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time: 10.64s | BCE: 0.1349 | Accuracy: 72.35% |
# End of validation epoch  17 | time:  0.59s | BCE: 0.1170 | Accuracy: 76.52% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 | 154/619 batches | 17.49ms/ batch | BCE: 0.1353 | Accuracy: 72.52% |
# Epoch 18 | 308/619 batches | 17.34ms/ batch | BCE: 0.1321 | Accuracy: 72.69% |
# Epoch 18 | 462/619 batches | 17.26ms/ batch | BCE: 0.1327 | Accuracy: 72.84% |
# Epoch 18 | 616/619 batches | 17.21ms/ batch | BCE: 0.1303 | Accuracy: 73.54% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time: 10.67s | BCE: 0.1301 | Accuracy: 73.62% |
# End of validation epoch  18 | time:  0.56s | BCE: 0.1155 | Accuracy: 77.07% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 | 154/619 batches | 17.39ms/ batch | BCE: 0.1211 | Accuracy: 75.12% |
# Epoch 19 | 308/619 batches | 17.27ms/ batch | BCE: 0.1203 | Accuracy: 74.90% |
# Epoch 19 | 462/619 batches | 17.21ms/ batch | BCE: 0.1206 | Accuracy: 74.91% |
# Epoch 19 | 616/619 batches | 17.15ms/ batch | BCE: 0.1225 | Accuracy: 74.53% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time: 10.63s | BCE: 0.1226 | Accuracy: 74.50% |
# End of validation epoch  19 | time:  0.55s | BCE: 0.1127 | Accuracy: 78.12% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 | 154/619 batches | 17.37ms/ batch | BCE: 0.1150 | Accuracy: 76.42% |
# Epoch 20 | 308/619 batches | 17.23ms/ batch | BCE: 0.1160 | Accuracy: 76.79% |
# Epoch 20 | 462/619 batches | 17.15ms/ batch | BCE: 0.1170 | Accuracy: 76.70% |
# Epoch 20 | 616/619 batches | 17.13ms/ batch | BCE: 0.1178 | Accuracy: 76.21% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time: 10.62s | BCE: 0.1180 | Accuracy: 76.13% |
# End of validation epoch  20 | time:  0.56s | BCE: 0.1103 | Accuracy: 78.29% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 21 | 154/619 batches | 17.29ms/ batch | BCE: 0.1140 | Accuracy: 76.50% |
# Epoch 21 | 308/619 batches | 17.21ms/ batch | BCE: 0.1135 | Accuracy: 76.77% |
# Epoch 21 | 462/619 batches | 17.17ms/ batch | BCE: 0.1122 | Accuracy: 77.15% |
# Epoch 21 | 616/619 batches | 17.14ms/ batch | BCE: 0.1122 | Accuracy: 76.95% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  21 | time: 10.63s | BCE: 0.1122 | Accuracy: 76.95% |
# End of validation epoch  21 | time:  0.60s | BCE: 0.1067 | Accuracy: 78.35% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 22 | 154/619 batches | 17.58ms/ batch | BCE: 0.1083 | Accuracy: 77.68% |
# Epoch 22 | 308/619 batches | 17.38ms/ batch | BCE: 0.1107 | Accuracy: 77.64% |
# Epoch 22 | 462/619 batches | 17.28ms/ batch | BCE: 0.1098 | Accuracy: 77.68% |
# Epoch 22 | 616/619 batches | 17.23ms/ batch | BCE: 0.1099 | Accuracy: 77.67% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  22 | time: 10.69s | BCE: 0.1100 | Accuracy: 77.63% |
# End of validation epoch  22 | time:  0.56s | BCE: 0.1059 | Accuracy: 78.12% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 23 | 154/619 batches | 17.38ms/ batch | BCE: 0.1052 | Accuracy: 77.72% |
# Epoch 23 | 308/619 batches | 17.21ms/ batch | BCE: 0.1047 | Accuracy: 78.57% |
# Epoch 23 | 462/619 batches | 17.21ms/ batch | BCE: 0.1048 | Accuracy: 78.71% |
# Epoch 23 | 616/619 batches | 17.16ms/ batch | BCE: 0.1048 | Accuracy: 78.64% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  23 | time: 10.64s | BCE: 0.1047 | Accuracy: 78.70% |
# End of validation epoch  23 | time:  0.56s | BCE: 0.1034 | Accuracy: 79.89% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 24 | 154/619 batches | 17.35ms/ batch | BCE: 0.0998 | Accuracy: 80.24% |
# Epoch 24 | 308/619 batches | 17.19ms/ batch | BCE: 0.1012 | Accuracy: 79.99% |
# Epoch 24 | 462/619 batches | 17.19ms/ batch | BCE: 0.1032 | Accuracy: 79.46% |
# Epoch 24 | 616/619 batches | 17.20ms/ batch | BCE: 0.1018 | Accuracy: 79.73% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  24 | time: 10.67s | BCE: 0.1018 | Accuracy: 79.71% |
# End of validation epoch  24 | time:  0.57s | BCE: 0.1010 | Accuracy: 79.07% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 25 | 154/619 batches | 17.39ms/ batch | BCE: 0.0993 | Accuracy: 79.79% |
# Epoch 25 | 308/619 batches | 17.21ms/ batch | BCE: 0.0987 | Accuracy: 79.97% |
# Epoch 25 | 462/619 batches | 17.15ms/ batch | BCE: 0.0980 | Accuracy: 80.33% |
# Epoch 25 | 616/619 batches | 17.15ms/ batch | BCE: 0.0978 | Accuracy: 80.41% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  25 | time: 10.64s | BCE: 0.0982 | Accuracy: 80.30% |
# End of validation epoch  25 | time:  0.64s | BCE: 0.0992 | Accuracy: 80.37% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 26 | 154/619 batches | 17.34ms/ batch | BCE: 0.0924 | Accuracy: 82.10% |
# Epoch 26 | 308/619 batches | 17.17ms/ batch | BCE: 0.0921 | Accuracy: 81.80% |
# Epoch 26 | 462/619 batches | 17.12ms/ batch | BCE: 0.0938 | Accuracy: 81.29% |
# Epoch 26 | 616/619 batches | 17.10ms/ batch | BCE: 0.0952 | Accuracy: 80.96% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  26 | time: 10.60s | BCE: 0.0952 | Accuracy: 80.96% |
# End of validation epoch  26 | time:  0.60s | BCE: 0.0977 | Accuracy: 80.19% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 27 | 154/619 batches | 17.40ms/ batch | BCE: 0.0947 | Accuracy: 81.01% |
# Epoch 27 | 308/619 batches | 17.21ms/ batch | BCE: 0.0916 | Accuracy: 81.96% |
# Epoch 27 | 462/619 batches | 17.14ms/ batch | BCE: 0.0916 | Accuracy: 81.82% |
# Epoch 27 | 616/619 batches | 17.12ms/ batch | BCE: 0.0903 | Accuracy: 81.96% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  27 | time: 10.62s | BCE: 0.0904 | Accuracy: 81.95% |
# End of validation epoch  27 | time:  0.55s | BCE: 0.0964 | Accuracy: 80.83% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 28 | 154/619 batches | 17.58ms/ batch | BCE: 0.0869 | Accuracy: 83.04% |
# Epoch 28 | 308/619 batches | 17.31ms/ batch | BCE: 0.0873 | Accuracy: 82.75% |
# Epoch 28 | 462/619 batches | 17.22ms/ batch | BCE: 0.0880 | Accuracy: 82.64% |
# Epoch 28 | 616/619 batches | 17.17ms/ batch | BCE: 0.0884 | Accuracy: 82.73% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  28 | time: 10.65s | BCE: 0.0886 | Accuracy: 82.67% |
# End of validation epoch  28 | time:  0.61s | BCE: 0.0953 | Accuracy: 80.40% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 29 | 154/619 batches | 17.28ms/ batch | BCE: 0.0843 | Accuracy: 83.40% |
# Epoch 29 | 308/619 batches | 17.11ms/ batch | BCE: 0.0850 | Accuracy: 83.14% |
# Epoch 29 | 462/619 batches | 17.10ms/ batch | BCE: 0.0853 | Accuracy: 82.81% |
# Epoch 29 | 616/619 batches | 17.08ms/ batch | BCE: 0.0854 | Accuracy: 83.09% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  29 | time: 10.59s | BCE: 0.0854 | Accuracy: 83.08% |
# End of validation epoch  29 | time:  0.55s | BCE: 0.0930 | Accuracy: 81.25% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 30 | 154/619 batches | 17.35ms/ batch | BCE: 0.0799 | Accuracy: 84.29% |
# Epoch 30 | 308/619 batches | 17.17ms/ batch | BCE: 0.0794 | Accuracy: 84.33% |
# Epoch 30 | 462/619 batches | 17.16ms/ batch | BCE: 0.0803 | Accuracy: 84.43% |
# Epoch 30 | 616/619 batches | 17.15ms/ batch | BCE: 0.0802 | Accuracy: 84.42% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  30 | time: 10.63s | BCE: 0.0802 | Accuracy: 84.41% |
# End of validation epoch  30 | time:  0.56s | BCE: 0.0923 | Accuracy: 81.73% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 31 | 154/619 batches | 17.32ms/ batch | BCE: 0.0767 | Accuracy: 85.23% |
# Epoch 31 | 308/619 batches | 17.19ms/ batch | BCE: 0.0769 | Accuracy: 85.02% |
# Epoch 31 | 462/619 batches | 17.14ms/ batch | BCE: 0.0768 | Accuracy: 84.94% |
# Epoch 31 | 616/619 batches | 17.11ms/ batch | BCE: 0.0772 | Accuracy: 84.94% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  31 | time: 10.61s | BCE: 0.0771 | Accuracy: 85.00% |
# End of validation epoch  31 | time:  0.55s | BCE: 0.0929 | Accuracy: 82.05% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 32 | 154/619 batches | 17.38ms/ batch | BCE: 0.0726 | Accuracy: 85.67% |
# Epoch 32 | 308/619 batches | 17.24ms/ batch | BCE: 0.0728 | Accuracy: 85.25% |
# Epoch 32 | 462/619 batches | 17.20ms/ batch | BCE: 0.0739 | Accuracy: 85.38% |
# Epoch 32 | 616/619 batches | 17.17ms/ batch | BCE: 0.0744 | Accuracy: 85.37% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  32 | time: 10.65s | BCE: 0.0744 | Accuracy: 85.35% |
# End of validation epoch  32 | time:  0.55s | BCE: 0.0930 | Accuracy: 82.28% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 33 | 154/619 batches | 17.39ms/ batch | BCE: 0.0690 | Accuracy: 85.84% |
# Epoch 33 | 308/619 batches | 17.26ms/ batch | BCE: 0.0690 | Accuracy: 86.32% |
# Epoch 33 | 462/619 batches | 17.21ms/ batch | BCE: 0.0695 | Accuracy: 86.36% |
# Epoch 33 | 616/619 batches | 17.15ms/ batch | BCE: 0.0698 | Accuracy: 86.20% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  33 | time: 10.63s | BCE: 0.0696 | Accuracy: 86.24% |
# End of validation epoch  33 | time:  0.55s | BCE: 0.0899 | Accuracy: 82.20% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 34 | 154/619 batches | 17.32ms/ batch | BCE: 0.0696 | Accuracy: 86.77% |
# Epoch 34 | 308/619 batches | 17.21ms/ batch | BCE: 0.0675 | Accuracy: 86.89% |
# Epoch 34 | 462/619 batches | 17.18ms/ batch | BCE: 0.0691 | Accuracy: 86.42% |
# Epoch 34 | 616/619 batches | 17.13ms/ batch | BCE: 0.0688 | Accuracy: 86.62% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  34 | time: 10.62s | BCE: 0.0690 | Accuracy: 86.59% |
# End of validation epoch  34 | time:  0.54s | BCE: 0.0963 | Accuracy: 80.83% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 35 | 154/619 batches | 17.22ms/ batch | BCE: 0.0632 | Accuracy: 87.34% |
# Epoch 35 | 308/619 batches | 17.23ms/ batch | BCE: 0.0648 | Accuracy: 87.30% |
# Epoch 35 | 462/619 batches | 17.21ms/ batch | BCE: 0.0652 | Accuracy: 87.32% |
# Epoch 35 | 616/619 batches | 17.20ms/ batch | BCE: 0.0660 | Accuracy: 87.31% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  35 | time: 10.67s | BCE: 0.0660 | Accuracy: 87.32% |
# End of validation epoch  35 | time:  0.58s | BCE: 0.0898 | Accuracy: 82.61% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 36 | 154/619 batches | 17.41ms/ batch | BCE: 0.0595 | Accuracy: 88.80% |
# Epoch 36 | 308/619 batches | 17.23ms/ batch | BCE: 0.0613 | Accuracy: 88.39% |
# Epoch 36 | 462/619 batches | 17.18ms/ batch | BCE: 0.0615 | Accuracy: 88.43% |
# Epoch 36 | 616/619 batches | 17.14ms/ batch | BCE: 0.0615 | Accuracy: 88.48% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  36 | time: 10.63s | BCE: 0.0615 | Accuracy: 88.49% |
# End of validation epoch  36 | time:  0.55s | BCE: 0.0911 | Accuracy: 83.33% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 37 | 154/619 batches | 17.46ms/ batch | BCE: 0.0581 | Accuracy: 89.04% |
# Epoch 37 | 308/619 batches | 17.31ms/ batch | BCE: 0.0596 | Accuracy: 89.08% |
# Epoch 37 | 462/619 batches | 17.21ms/ batch | BCE: 0.0610 | Accuracy: 88.60% |
# Epoch 37 | 616/619 batches | 17.16ms/ batch | BCE: 0.0608 | Accuracy: 88.72% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  37 | time: 10.64s | BCE: 0.0606 | Accuracy: 88.76% |
# End of validation epoch  37 | time:  0.54s | BCE: 0.0913 | Accuracy: 82.74% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 38 | 154/619 batches | 17.33ms/ batch | BCE: 0.0586 | Accuracy: 89.00% |
# Epoch 38 | 308/619 batches | 17.18ms/ batch | BCE: 0.0581 | Accuracy: 89.29% |
# Epoch 38 | 462/619 batches | 17.18ms/ batch | BCE: 0.0587 | Accuracy: 88.79% |
# Epoch 38 | 616/619 batches | 17.15ms/ batch | BCE: 0.0571 | Accuracy: 89.25% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  38 | time: 10.64s | BCE: 0.0571 | Accuracy: 89.23% |
# End of validation epoch  38 | time:  0.56s | BCE: 0.0904 | Accuracy: 82.68% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 39 | 154/619 batches | 17.36ms/ batch | BCE: 0.0556 | Accuracy: 89.73% |
# Epoch 39 | 308/619 batches | 17.27ms/ batch | BCE: 0.0561 | Accuracy: 89.14% |
# Epoch 39 | 462/619 batches | 17.23ms/ batch | BCE: 0.0569 | Accuracy: 88.91% |
# Epoch 39 | 616/619 batches | 17.19ms/ batch | BCE: 0.0565 | Accuracy: 89.00% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  39 | time: 10.66s | BCE: 0.0565 | Accuracy: 89.01% |
# End of validation epoch  39 | time:  0.63s | BCE: 0.0899 | Accuracy: 83.72% |
# ---------------------------------------------------------------------------------------------------
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 40 | 154/619 batches | 17.32ms/ batch | BCE: 0.0571 | Accuracy: 89.65% |
# Epoch 40 | 308/619 batches | 17.20ms/ batch | BCE: 0.0580 | Accuracy: 88.84% |
# Epoch 40 | 462/619 batches | 17.16ms/ batch | BCE: 0.0575 | Accuracy: 88.99% |
# Epoch 40 | 616/619 batches | 17.17ms/ batch | BCE: 0.0570 | Accuracy: 89.11% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  40 | time: 10.64s | BCE: 0.0571 | Accuracy: 89.12% |
# End of validation epoch  40 | time:  0.55s | BCE: 0.0891 | Accuracy: 83.88% |
# ---------------------------------------------------------------------------------------------------
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 41 | 154/619 batches | 17.35ms/ batch | BCE: 0.0502 | Accuracy: 90.26% |
# Epoch 41 | 308/619 batches | 17.22ms/ batch | BCE: 0.0532 | Accuracy: 89.96% |
# Epoch 41 | 462/619 batches | 17.17ms/ batch | BCE: 0.0520 | Accuracy: 90.19% |
# Epoch 41 | 616/619 batches | 17.13ms/ batch | BCE: 0.0516 | Accuracy: 90.38% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  41 | time: 10.63s | BCE: 0.0516 | Accuracy: 90.39% |
# End of validation epoch  41 | time:  0.54s | BCE: 0.0882 | Accuracy: 83.24% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 42 | 154/619 batches | 17.40ms/ batch | BCE: 0.0490 | Accuracy: 91.15% |
# Epoch 42 | 308/619 batches | 17.27ms/ batch | BCE: 0.0492 | Accuracy: 90.95% |
# Epoch 42 | 462/619 batches | 17.18ms/ batch | BCE: 0.0503 | Accuracy: 90.81% |
# Epoch 42 | 616/619 batches | 17.14ms/ batch | BCE: 0.0512 | Accuracy: 90.51% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  42 | time: 10.63s | BCE: 0.0512 | Accuracy: 90.54% |
# End of validation epoch  42 | time:  0.61s | BCE: 0.0887 | Accuracy: 83.62% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 43 | 154/619 batches | 17.39ms/ batch | BCE: 0.0476 | Accuracy: 91.84% |
# Epoch 43 | 308/619 batches | 17.27ms/ batch | BCE: 0.0485 | Accuracy: 91.15% |
# Epoch 43 | 462/619 batches | 17.31ms/ batch | BCE: 0.0494 | Accuracy: 90.61% |
# Epoch 43 | 616/619 batches | 17.25ms/ batch | BCE: 0.0487 | Accuracy: 90.77% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  43 | time: 10.70s | BCE: 0.0486 | Accuracy: 90.78% |
# End of validation epoch  43 | time:  0.53s | BCE: 0.0843 | Accuracy: 84.13% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 44 | 154/619 batches | 17.44ms/ batch | BCE: 0.0429 | Accuracy: 92.25% |
# Epoch 44 | 308/619 batches | 17.28ms/ batch | BCE: 0.0458 | Accuracy: 91.78% |
# Epoch 44 | 462/619 batches | 17.21ms/ batch | BCE: 0.0463 | Accuracy: 91.64% |
# Epoch 44 | 616/619 batches | 17.19ms/ batch | BCE: 0.0464 | Accuracy: 91.63% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  44 | time: 10.66s | BCE: 0.0465 | Accuracy: 91.64% |
# End of validation epoch  44 | time:  0.55s | BCE: 0.0904 | Accuracy: 83.62% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 45 | 154/619 batches | 17.32ms/ batch | BCE: 0.0424 | Accuracy: 92.25% |
# Epoch 45 | 308/619 batches | 17.17ms/ batch | BCE: 0.0415 | Accuracy: 92.47% |
# Epoch 45 | 462/619 batches | 17.13ms/ batch | BCE: 0.0435 | Accuracy: 91.79% |
# Epoch 45 | 616/619 batches | 17.13ms/ batch | BCE: 0.0442 | Accuracy: 91.53% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  45 | time: 10.62s | BCE: 0.0442 | Accuracy: 91.52% |
# End of validation epoch  45 | time:  0.55s | BCE: 0.0888 | Accuracy: 84.12% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# Epoch 46 | 154/619 batches | 17.40ms/ batch | BCE: 0.0417 | Accuracy: 92.05% |
# Epoch 46 | 308/619 batches | 17.34ms/ batch | BCE: 0.0427 | Accuracy: 91.82% |
# Epoch 46 | 462/619 batches | 17.25ms/ batch | BCE: 0.0426 | Accuracy: 91.67% |
# Epoch 46 | 616/619 batches | 17.20ms/ batch | BCE: 0.0423 | Accuracy: 91.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  46 | time: 10.67s | BCE: 0.0424 | Accuracy: 91.79% |
# End of validation epoch  46 | time:  0.63s | BCE: 0.0910 | Accuracy: 84.54% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 47 | 154/619 batches | 17.40ms/ batch | BCE: 0.0434 | Accuracy: 92.09% |
# Epoch 47 | 308/619 batches | 17.29ms/ batch | BCE: 0.0412 | Accuracy: 92.65% |
# Epoch 47 | 462/619 batches | 17.23ms/ batch | BCE: 0.0404 | Accuracy: 92.84% |
# Epoch 47 | 616/619 batches | 17.18ms/ batch | BCE: 0.0401 | Accuracy: 92.92% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  47 | time: 10.65s | BCE: 0.0400 | Accuracy: 92.92% |
# End of validation epoch  47 | time:  0.55s | BCE: 0.0871 | Accuracy: 83.54% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 48 | 154/619 batches | 17.36ms/ batch | BCE: 0.0372 | Accuracy: 93.43% |
# Epoch 48 | 308/619 batches | 17.21ms/ batch | BCE: 0.0368 | Accuracy: 93.47% |
# Epoch 48 | 462/619 batches | 17.17ms/ batch | BCE: 0.0371 | Accuracy: 93.37% |
# Epoch 48 | 616/619 batches | 17.13ms/ batch | BCE: 0.0374 | Accuracy: 93.33% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  48 | time: 10.62s | BCE: 0.0379 | Accuracy: 93.27% |
# End of validation epoch  48 | time:  0.55s | BCE: 0.0885 | Accuracy: 85.08% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 49 | 154/619 batches | 17.56ms/ batch | BCE: 0.0402 | Accuracy: 92.49% |
# Epoch 49 | 308/619 batches | 17.32ms/ batch | BCE: 0.0370 | Accuracy: 93.24% |
# Epoch 49 | 462/619 batches | 17.24ms/ batch | BCE: 0.0373 | Accuracy: 93.26% |
# Epoch 49 | 616/619 batches | 17.20ms/ batch | BCE: 0.0370 | Accuracy: 93.28% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  49 | time: 10.67s | BCE: 0.0371 | Accuracy: 93.28% |
# End of validation epoch  49 | time:  0.59s | BCE: 0.0888 | Accuracy: 84.12% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 50 | 154/619 batches | 17.39ms/ batch | BCE: 0.0381 | Accuracy: 93.22% |
# Epoch 50 | 308/619 batches | 17.21ms/ batch | BCE: 0.0364 | Accuracy: 93.43% |
# Epoch 50 | 462/619 batches | 17.17ms/ batch | BCE: 0.0353 | Accuracy: 93.70% |
# Epoch 50 | 616/619 batches | 17.14ms/ batch | BCE: 0.0344 | Accuracy: 93.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  50 | time: 10.63s | BCE: 0.0345 | Accuracy: 93.84% |
# End of validation epoch  50 | time:  0.55s | BCE: 0.0880 | Accuracy: 84.52% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(t_accu, c='b', label='Training set accuracy')
plt.plot(v_accu, c='r', label='Validation set accuracy')
plt.title('Accuracy vs Epochs / GRU-CNN Model')
plt.legend()
plt.show()

# %%
G_model.load_state_dict(torch.load(Para.MODEL_SAVE_PATH_2A))
validate_test(G_model, 0, test=True)
# Out:
# End of Test | time:  0.67s | BCE: 0.0936 | Accuracy: 84.21% |
# ---------------------------------------------------------------------------------------------------
# (0.09364234408936821, 0.8421474358974359)
